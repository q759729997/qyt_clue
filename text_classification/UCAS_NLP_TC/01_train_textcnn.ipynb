# %% [markdown]
# 01_TEXTCNN文本分类，使用原始数据

# %%
# 显卡查看
! nvidia-smi
# Out:
# Sun Jul  5 02:25:51 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P0    30W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# 依赖安装
! pip install fastNLP
# Out:
# Requirement already satisfied: fastNLP in /usr/local/lib/python3.6/dist-packages (0.5.5)
# Requirement already satisfied: prettytable>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from fastNLP) (0.7.2)
# Requirement already satisfied: nltk>=3.4.1 in /usr/local/lib/python3.6/dist-packages (from fastNLP) (3.5)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.6/dist-packages (from fastNLP) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from fastNLP) (2.23.0)
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (from fastNLP) (2.2.4)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from fastNLP) (1.5.1+cu101)
# Requirement already satisfied: numpy>=1.14.2 in /usr/local/lib/python3.6/dist-packages (from fastNLP) (1.18.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from fastNLP) (2019.12.20)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from nltk>=3.4.1->fastNLP) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from nltk>=3.4.1->fastNLP) (0.15.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->fastNLP) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->fastNLP) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->fastNLP) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->fastNLP) (1.24.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (1.0.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (3.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (2.0.3)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (0.4.1)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (7.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (0.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (47.3.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (1.0.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.0->fastNLP) (0.16.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy->fastNLP) (1.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy->fastNLP) (3.1.0)

# %% [markdown]
# 加载数据集

# %%
import sys

from fastNLP.core import Const

sys.path.insert(0, '/content/drive/My Drive/my_framework/qyt_clue/')  # 定义搜索路径的优先顺序，序号从0开始，表示最大优先级

import myClue  # noqa
print('myClue module path :{}'.format(myClue.__file__))  # 输出测试模块文件位置
from myClue.core import logger  # noqa
from myClue.core.utils import print_data_bundle  # noqa
from myClue.tools.serialize import save_serialize_obj  # noqa
from myClue.loader.classification import THUCNewsLoader  # noqa
from myClue.pipe.classification import THUCNewsPipe  # noqa
# Out:
# myClue module path :/content/drive/My Drive/my_framework/qyt_clue/myClue/__init__.py

# %%
train_file_config = {
        'train': '/content/drive/My Drive/game/UCAS_NLP_TC/data_01_shuffle/traindata.txt',
        'dev': '/content/drive/My Drive/game/UCAS_NLP_TC/data_01_shuffle/devdata.txt',
    }

# %%
logger.info('数据加载')
data_loader = THUCNewsLoader()
data_bundle = data_loader.load(train_file_config)
print_data_bundle(data_bundle)
logger.info('数据预处理')
data_pipe = THUCNewsPipe(tokenizer='white_space')
data_bundle = data_pipe.process(data_bundle)
data_bundle.rename_field(field_name=Const.CHAR_INPUT, new_field_name=Const.INPUT, ignore_miss_dataset=True, rename_vocab=True)
print_data_bundle(data_bundle)
# Out:
# 2020-07-05 02:25:58 I [<ipython-input-5-d23eb2358db5>:1] 数据加载
# 2020-07-05 02:25:58 I [utils.py:16] dataset name : train
# 2020-07-05 02:25:58 I [utils.py:17] dataset len : 2500
# 2020-07-05 02:25:58 I [utils.py:18] dataset example :
# 2020-07-05 02:25:58 I [utils.py:19]
# +-------------------------------------------+-------------+
# | raw_chars                                 | target      |
# +-------------------------------------------+-------------+
# | 近日 ， 胡杏儿 以 品牌 挚友 及 公益 大... | EnterSports |
# | 虎 扑 1月 14日 讯 根据 《 世界 体育报...  | EnterSports |
# | 日前 ， 有 媒体 爆料 美团 正在 招聘 游... | Economics   |
# | 记者 1日 从 天津 大学 获悉 ， 该 校 太... | Technology  |
# | 贯彻 落实 党 的 十九 大 的 战略 部署 ...  | Military    |
# +-------------------------------------------+-------------+
# 2020-07-05 02:25:58 I [utils.py:20] dataset 输出各个field的被设置成input和target的情况 :
# 2020-07-05 02:25:58 I [utils.py:21]
# +-------------+-----------+--------+
# | field_names | raw_chars | target |
# +-------------+-----------+--------+
# |   is_input  |   False   | False  |
# |  is_target  |   False   | False  |
# | ignore_type |           |        |
# |  pad_value  |           |        |
# +-------------+-----------+--------+
# 2020-07-05 02:25:58 I [utils.py:16] dataset name : dev
# 2020-07-05 02:25:58 I [utils.py:17] dataset len : 500
# 2020-07-05 02:25:58 I [utils.py:18] dataset example :
# 2020-07-05 02:25:58 I [utils.py:19]
# +-------------------------------------------+-------------+
# | raw_chars                                 | target      |
# +-------------------------------------------+-------------+
# | 虎 扑 1月 13日 讯 在 魔术 与 凯尔特人...  | EnterSports |
# | 刘国梁 接替 蔡振华 当选 中国 乒协 掌门... | EnterSports |
# | 新浪 科技讯 9月 7日 晚间 消息 ， 针对...  | Technology  |
# | 今年 红 土 赛季 之前 ， 对于 纳达尔 能... | EnterSports |
# | 北京 时间 1月 1日 19:30 , 广东 电视台...  | EnterSports |
# +-------------------------------------------+-------------+
# 2020-07-05 02:25:58 I [utils.py:20] dataset 输出各个field的被设置成input和target的情况 :
# 2020-07-05 02:25:58 I [utils.py:21]
# +-------------+-----------+--------+
# | field_names | raw_chars | target |
# +-------------+-----------+--------+
# |   is_input  |   False   | False  |
# |  is_target  |   False   | False  |
# | ignore_type |           |        |
# |  pad_value  |           |        |
# +-------------+-----------+--------+
# 2020-07-05 02:25:58 I [<ipython-input-5-d23eb2358db5>:5] 数据预处理
# +-------------+-----------+--------+
# | field_names | raw_chars | target |
# +-------------+-----------+--------+
# |   is_input  |   False   | False  |
# |  is_target  |   False   | False  |
# | ignore_type |           |        |
# |  pad_value  |           |        |
# +-------------+-----------+--------+
# +-------------+-----------+--------+
# | field_names | raw_chars | target |
# +-------------+-----------+--------+
# |   is_input  |   False   | False  |
# |  is_target  |   False   | False  |
# | ignore_type |           |        |
# |  pad_value  |           |        |
# +-------------+-----------+--------+
# 2020-07-05 02:26:07 I [utils.py:16] dataset name : train
# 2020-07-05 02:26:07 I [utils.py:17] dataset len : 2500
# 2020-07-05 02:26:07 I [utils.py:18] dataset example :
# 2020-07-05 02:26:07 I [utils.py:19]
# +---------------------+--------+--------------------+---------+--------------------+
# | raw_chars           | target | chars              | seq_len | words              |
# +---------------------+--------+--------------------+---------+--------------------+
# | 近日 ， 胡杏儿 ...  | 0      | ['近日', '，', ... | 92      | [692, 2, 24244,... |
# | 虎 扑 1月 14日 ...  | 0      | ['虎', '扑', '1... | 124     | [2608, 3871, 27... |
# | 日前 ， 有 媒体...  | 1      | ['日前', '，', ... | 169     | [1343, 2, 14, 2... |
# | 记者 1日 从 天津... | 2      | ['记者', '1日',... | 346     | [95, 991, 57, 1... |
# | 贯彻 落实 党 的...  | 3      | ['贯彻', '落实'... | 716     | [1531, 694, 286... |
# +---------------------+--------+--------------------+---------+--------------------+
# 2020-07-05 02:26:07 I [utils.py:20] dataset 输出各个field的被设置成input和target的情况 :
# 2020-07-05 02:26:07 I [utils.py:21]
# +-------------+-----------+--------+-----------+---------+-------+
# | field_names | raw_chars | target | raw_words | seq_len | words |
# +-------------+-----------+--------+-----------+---------+-------+
# |   is_input  |   False   | False  |   False   |   True  |  True |
# |  is_target  |   False   |  True  |   False   |  False  | False |
# | ignore_type |           | False  |           |  False  | False |
# |  pad_value  |           |   0    |           |    0    |   0   |
# +-------------+-----------+--------+-----------+---------+-------+
# 2020-07-05 02:26:07 I [utils.py:16] dataset name : dev
# 2020-07-05 02:26:07 I [utils.py:17] dataset len : 500
# 2020-07-05 02:26:07 I [utils.py:18] dataset example :
# 2020-07-05 02:26:07 I [utils.py:19]
# +---------------------+--------+---------------------+---------+--------------------+
# | raw_chars           | target | chars               | seq_len | words              |
# +---------------------+--------+---------------------+---------+--------------------+
# | 虎 扑 1月 13日 ...  | 0      | ['虎', '扑', '1...  | 46      | [2608, 3871, 27... |
# | 刘国梁 接替 蔡振... | 0      | ['刘国梁', '接替... | 393     | [19109, 7943, 2... |
# | 新浪 科技讯 9月...  | 2      | ['新浪', '科技讯... | 513     | [1053, 2952, 57... |
# | 今年 红 土 赛季...  | 0      | ['今年', '红', ...  | 569     | [155, 1481, 344... |
# | 北京 时间 1月 1...  | 0      | ['北京', '时间'...  | 979     | [160, 109, 270,... |
# +---------------------+--------+---------------------+---------+--------------------+
# 2020-07-05 02:26:07 I [utils.py:20] dataset 输出各个field的被设置成input和target的情况 :
# 2020-07-05 02:26:07 I [utils.py:21]
# +-------------+-----------+--------+-----------+---------+-------+
# | field_names | raw_chars | target | raw_words | seq_len | words |
# +-------------+-----------+--------+-----------+---------+-------+
# |   is_input  |   False   | False  |   False   |   True  |  True |
# |  is_target  |   False   |  True  |   False   |  False  | False |
# | ignore_type |           | False  |           |  False  | False |
# |  pad_value  |           |   0    |           |    0    |   0   |
# +-------------+-----------+--------+-----------+---------+-------+
# +-------------+-----------+--------+-----------+---------+-------+
# | field_names | raw_chars | target | raw_words | seq_len | words |
# +-------------+-----------+--------+-----------+---------+-------+
# |   is_input  |   False   | False  |   False   |   True  |  True |
# |  is_target  |   False   |  True  |   False   |  False  | False |
# | ignore_type |           | False  |           |  False  | False |
# |  pad_value  |           |   0    |           |    0    |   0   |
# +-------------+-----------+--------+-----------+---------+-------+
# +-------------+-----------+--------+-----------+---------+-------+
# | field_names | raw_chars | target | raw_words | seq_len | words |
# +-------------+-----------+--------+-----------+---------+-------+
# |   is_input  |   False   | False  |   False   |   True  |  True |
# |  is_target  |   False   |  True  |   False   |  False  | False |
# | ignore_type |           | False  |           |  False  | False |
# |  pad_value  |           |   0    |           |    0    |   0   |
# +-------------+-----------+--------+-----------+---------+-------+

# %% [markdown]
# 模型训练

# %%
import os
import sys
import time

import torch

from fastNLP import Const
from fastNLP.embeddings import StaticEmbedding
from fastNLP.models import CNNText
from fastNLP import Trainer
from fastNLP import CrossEntropyLoss
from torch.optim import Adam
from fastNLP import Tester

from myClue.core.metrics import ClassifyFPreRecMetric  # noqa
from myClue.core.callback import EarlyStopCallback  # noqa
from myClue.tools.serialize import save_serialize_obj  # noqa
from myClue.tools.file import init_file_path  # noqa

# %%
model_path = '/content/drive/My Drive/game/UCAS_NLP_TC/models/01_train_textcnn'
init_file_path(model_path)
logger.add_file_handler(os.path.join(model_path, 'log_{}.txt'.format(time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime()))))  # 日志写入文件
char_vocab_pkl_file = os.path.join(model_path, 'vocab_char.pkl')
target_vocab_pkl_file = os.path.join(model_path, 'target_char.pkl')
logger.warn('获取词典')
char_vocab = data_bundle.get_vocab('words')
logger.info('char_vocab:{}'.format(char_vocab))
target_vocab = data_bundle.get_vocab('target')
logger.info('target_vocab:{}'.format(target_vocab))
save_serialize_obj(char_vocab, char_vocab_pkl_file)
save_serialize_obj(target_vocab, target_vocab_pkl_file)
logger.info('词典序列化:{}'.format(char_vocab_pkl_file))
logger.warn('选择预训练词向量')
model_dir_or_name = '/content/drive/My Drive/data/embed/ctb.50d.vec'
word2vec_embed = StaticEmbedding(char_vocab, model_dir_or_name=model_dir_or_name)
logger.warn('神经网络模型')
model = CNNText(word2vec_embed, num_classes=len(target_vocab))
logger.info(model)
logger.warn('训练超参数设定')
loss = CrossEntropyLoss()
optimizer = Adam([param for param in model.parameters() if param.requires_grad])
# metric = AccuracyMetric()
metric = ClassifyFPreRecMetric(tag_vocab=data_bundle.get_vocab(Const.TARGET), only_gross=False)  # 若only_gross=False, 即还会返回各个label的metric统计值
device = 'cuda' if torch.cuda.is_available() else 'cpu'  # 如果有gpu的话在gpu上运行，训练速度会更快
logger.info('device:{}'.format(device))
batch_size = 32
n_epochs = 200
early_stopping = 10
trainer = Trainer(
    save_path=model_path,
    train_data=data_bundle.get_dataset('train'),
    model=model,
    loss=loss,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epochs=n_epochs,
    dev_data=data_bundle.get_dataset('dev'),
    metrics=metric,
    metric_key='f',
    device=device,
    callbacks=[EarlyStopCallback(early_stopping)])
logger.warn('开始训练')
trainer.train()
# Out:
# 2020-07-05 02:26:07 W [<ipython-input-7-bb04a629dc27>:6] 获取词典
# 2020-07-05 02:26:07 I [<ipython-input-7-bb04a629dc27>:8] char_vocab:Vocabulary(['近日', '，', '胡杏儿', '以', '品牌']...)
# 2020-07-05 02:26:07 I [<ipython-input-7-bb04a629dc27>:10] target_vocab:Vocabulary(['EnterSports', 'Economics', 'Technology', 'Military', 'Government']...)
# 2020-07-05 02:26:07 I [<ipython-input-7-bb04a629dc27>:13] 词典序列化:/content/drive/My Drive/game/UCAS_NLP_TC/models/01_train_textcnn/vocab_char.pkl
# 2020-07-05 02:26:07 W [<ipython-input-7-bb04a629dc27>:14] 选择预训练词向量
# Found 58423 out of 102541 words in the pre-training embedding.
# /pytorch/aten/src/ATen/native/TensorFactories.cpp:361: UserWarning: Deprecation warning: In a future PyTorch release torch.full will no longer return tensors of floating dtype by default. Instead, a bool fill_value will return a tensor of torch.bool dtype, and an integral fill_value will return a tensor of torch.long dtype. Set the optional `dtype` or `out` arguments to suppress this warning.
# 2020-07-05 02:26:14 W [<ipython-input-7-bb04a629dc27>:17] 神经网络模型
# 2020-07-05 02:26:14 I [<ipython-input-7-bb04a629dc27>:19] CNNText(
#   (embed): Embedding(
#     (embed): StaticEmbedding(
#       (dropout_layer): Dropout(p=0, inplace=False)
#       (embedding): Embedding(96465, 50, padding_idx=0)
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (conv_pool): ConvMaxpool(
#     (convs): ModuleList(
#       (0): Conv1d(50, 30, kernel_size=(1,), stride=(1,), bias=False)
#       (1): Conv1d(50, 40, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#       (2): Conv1d(50, 50, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#     )
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=120, out_features=5, bias=True)
# )
# 2020-07-05 02:26:14 W [<ipython-input-7-bb04a629dc27>:20] 训练超参数设定
# 2020-07-05 02:26:14 I [<ipython-input-7-bb04a629dc27>:26] device:cuda
# 2020-07-05 02:26:17 W [<ipython-input-7-bb04a629dc27>:43] 开始训练
# input fields after batch(if batch size is 2):
# 	seq_len: (1)type:torch.Tensor (2)dtype:torch.int64, (3)shape:torch.Size([2])
# 	words: (1)type:torch.Tensor (2)dtype:torch.int64, (3)shape:torch.Size([2, 124])
# target fields after batch(if batch size is 2):
# 	target: (1)type:torch.Tensor (2)dtype:torch.int64, (3)shape:torch.Size([2])
#
# training epochs started 2020-07-05-02-26-17-905161
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=15800.0), HTML(value='')), layout=Layout(…
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# Evaluate data in 0.23 seconds!
# 2020-07-05 02:26:20 W [callback.py:38] ======epoch : 1 , early stopping : 0/10======
# 2020-07-05 02:26:20 I [callback.py:40] metric_key : f, metric_value : 0.696
# 2020-07-05 02:26:20 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.887701, 'pre-EnterSports': 0.83, 'rec-EnterSports': 0.954023, 'f-Economics': 0.654867, 'pre-Economics': 0.74, 'rec-Economics': 0.587302, 'f-Technology': 0.6875, 'pre-Technology': 0.66, 'rec-Technology': 0.717391, 'f-Military': 0.730159, 'pre-Military': 0.69, 'rec-Military': 0.775281, 'f-Government': 0.543689, 'pre-Government': 0.56, 'rec-Government': 0.528302, 'f': 0.696, 'pre': 0.696, 'rec': 0.696}}
# Evaluation on dev at Epoch 1/200. Step:79/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.887701, pre-EnterSports=0.83, rec-EnterSports=0.954023, f-Economics=0.654867, pre-Economics=0.74, rec-Economics=0.587302, f-Technology=0.6875, pre-Technology=0.66, rec-Technology=0.717391, f-Military=0.730159, pre-Military=0.69, rec-Military=0.775281, f-Government=0.543689, pre-Government=0.56, rec-Government=0.528302, f=0.696, pre=0.696, rec=0.696
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# Evaluate data in 0.24 seconds!
# 2020-07-05 02:26:22 W [callback.py:38] ======epoch : 2 , early stopping : 0/10======
# 2020-07-05 02:26:22 I [callback.py:40] metric_key : f, metric_value : 0.728
# 2020-07-05 02:26:22 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.901408, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.849558, 'f-Economics': 0.663551, 'pre-Economics': 0.71, 'rec-Economics': 0.622807, 'f-Technology': 0.7, 'pre-Technology': 0.7, 'rec-Technology': 0.7, 'f-Military': 0.801887, 'pre-Military': 0.85, 'rec-Military': 0.758929, 'f-Government': 0.521739, 'pre-Government': 0.42, 'rec-Government': 0.688525, 'f': 0.728, 'pre': 0.728, 'rec': 0.728}}
# Evaluation on dev at Epoch 2/200. Step:158/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.901408, pre-EnterSports=0.96, rec-EnterSports=0.849558, f-Economics=0.663551, pre-Economics=0.71, rec-Economics=0.622807, f-Technology=0.7, pre-Technology=0.7, rec-Technology=0.7, f-Military=0.801887, pre-Military=0.85, rec-Military=0.758929, f-Government=0.521739, pre-Government=0.42, rec-Government=0.688525, f=0.728, pre=0.728, rec=0.728
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# Evaluate data in 0.24 seconds!
# 2020-07-05 02:26:25 W [callback.py:38] ======epoch : 3 , early stopping : 0/10======
# 2020-07-05 02:26:25 I [callback.py:40] metric_key : f, metric_value : 0.756
# 2020-07-05 02:26:25 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.95, 'pre-EnterSports': 0.95, 'rec-EnterSports': 0.95, 'f-Economics': 0.691943, 'pre-Economics': 0.73, 'rec-Economics': 0.657658, 'f-Technology': 0.757576, 'pre-Technology': 0.75, 'rec-Technology': 0.765306, 'f-Military': 0.788462, 'pre-Military': 0.82, 'rec-Military': 0.759259, 'f-Government': 0.579235, 'pre-Government': 0.53, 'rec-Government': 0.638554, 'f': 0.756, 'pre': 0.756, 'rec': 0.756}}
# Evaluation on dev at Epoch 3/200. Step:237/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.95, pre-EnterSports=0.95, rec-EnterSports=0.95, f-Economics=0.691943, pre-Economics=0.73, rec-Economics=0.657658, f-Technology=0.757576, pre-Technology=0.75, rec-Technology=0.765306, f-Military=0.788462, pre-Military=0.82, rec-Military=0.759259, f-Government=0.579235, pre-Government=0.53, rec-Government=0.638554, f=0.756, pre=0.756, rec=0.756
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# Evaluate data in 0.24 seconds!
# 2020-07-05 02:26:27 W [callback.py:38] ======epoch : 4 , early stopping : 0/10======
# 2020-07-05 02:26:27 I [callback.py:40] metric_key : f, metric_value : 0.77
# 2020-07-05 02:26:27 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.945813, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.932039, 'f-Economics': 0.683938, 'pre-Economics': 0.66, 'rec-Economics': 0.709677, 'f-Technology': 0.760976, 'pre-Technology': 0.78, 'rec-Technology': 0.742857, 'f-Military': 0.80402, 'pre-Military': 0.8, 'rec-Military': 0.808081, 'f-Government': 0.65, 'pre-Government': 0.65, 'rec-Government': 0.65, 'f': 0.77, 'pre': 0.77, 'rec': 0.77}}
# Evaluation on dev at Epoch 4/200. Step:316/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.945813, pre-EnterSports=0.96, rec-EnterSports=0.932039, f-Economics=0.683938, pre-Economics=0.66, rec-Economics=0.709677, f-Technology=0.760976, pre-Technology=0.78, rec-Technology=0.742857, f-Military=0.80402, pre-Military=0.8, rec-Military=0.808081, f-Government=0.65, pre-Government=0.65, rec-Government=0.65, f=0.77, pre=0.77, rec=0.77
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# Evaluate data in 0.23 seconds!
# 2020-07-05 02:26:29 W [callback.py:38] ======epoch : 5 , early stopping : 0/10======
# 2020-07-05 02:26:29 I [callback.py:40] metric_key : f, metric_value : 0.776
# 2020-07-05 02:26:29 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.950495, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.941176, 'f-Economics': 0.701422, 'pre-Economics': 0.74, 'rec-Economics': 0.666667, 'f-Technology': 0.762376, 'pre-Technology': 0.77, 'rec-Technology': 0.754902, 'f-Military': 0.8, 'pre-Military': 0.8, 'rec-Military': 0.8, 'f-Government': 0.659459, 'pre-Government': 0.61, 'rec-Government': 0.717647, 'f': 0.776, 'pre': 0.776, 'rec': 0.776}}
# Evaluation on dev at Epoch 5/200. Step:395/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.950495, pre-EnterSports=0.96, rec-EnterSports=0.941176, f-Economics=0.701422, pre-Economics=0.74, rec-Economics=0.666667, f-Technology=0.762376, pre-Technology=0.77, rec-Technology=0.754902, f-Military=0.8, pre-Military=0.8, rec-Military=0.8, f-Government=0.659459, pre-Government=0.61, rec-Government=0.717647, f=0.776, pre=0.776, rec=0.776
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:26:31 W [callback.py:38] ======epoch : 6 , early stopping : 0/10======
# 2020-07-05 02:26:31 I [callback.py:40] metric_key : f, metric_value : 0.77
# 2020-07-05 02:26:31 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.950495, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.941176, 'f-Economics': 0.69697, 'pre-Economics': 0.69, 'rec-Economics': 0.704082, 'f-Technology': 0.761905, 'pre-Technology': 0.72, 'rec-Technology': 0.808989, 'f-Military': 0.79602, 'pre-Military': 0.8, 'rec-Military': 0.792079, 'f-Government': 0.647619, 'pre-Government': 0.68, 'rec-Government': 0.618182, 'f': 0.77, 'pre': 0.77, 'rec': 0.77}}
# Evaluate data in 0.24 seconds!
# Evaluation on dev at Epoch 6/200. Step:474/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.950495, pre-EnterSports=0.96, rec-EnterSports=0.941176, f-Economics=0.69697, pre-Economics=0.69, rec-Economics=0.704082, f-Technology=0.761905, pre-Technology=0.72, rec-Technology=0.808989, f-Military=0.79602, pre-Military=0.8, rec-Military=0.792079, f-Government=0.647619, pre-Government=0.68, rec-Government=0.618182, f=0.77, pre=0.77, rec=0.77
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# Evaluate data in 0.23 seconds!
# 2020-07-05 02:26:34 W [callback.py:38] ======epoch : 7 , early stopping : 1/10======
# 2020-07-05 02:26:34 I [callback.py:40] metric_key : f, metric_value : 0.778
# 2020-07-05 02:26:34 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.945813, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.932039, 'f-Economics': 0.696078, 'pre-Economics': 0.71, 'rec-Economics': 0.682692, 'f-Technology': 0.771574, 'pre-Technology': 0.76, 'rec-Technology': 0.783505, 'f-Military': 0.808081, 'pre-Military': 0.8, 'rec-Military': 0.816327, 'f-Government': 0.666667, 'pre-Government': 0.66, 'rec-Government': 0.673469, 'f': 0.778, 'pre': 0.778, 'rec': 0.778}}
# Evaluation on dev at Epoch 7/200. Step:553/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.945813, pre-EnterSports=0.96, rec-EnterSports=0.932039, f-Economics=0.696078, pre-Economics=0.71, rec-Economics=0.682692, f-Technology=0.771574, pre-Technology=0.76, rec-Technology=0.783505, f-Military=0.808081, pre-Military=0.8, rec-Military=0.816327, f-Government=0.666667, pre-Government=0.66, rec-Government=0.673469, f=0.778, pre=0.778, rec=0.778
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# Evaluate data in 0.23 seconds!
# 2020-07-05 02:26:36 W [callback.py:38] ======epoch : 8 , early stopping : 0/10======
# 2020-07-05 02:26:36 I [callback.py:40] metric_key : f, metric_value : 0.784
# 2020-07-05 02:26:36 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.945813, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.932039, 'f-Economics': 0.692308, 'pre-Economics': 0.63, 'rec-Economics': 0.768293, 'f-Technology': 0.8, 'pre-Technology': 0.82, 'rec-Technology': 0.780952, 'f-Military': 0.82, 'pre-Military': 0.82, 'rec-Military': 0.82, 'f-Government': 0.657143, 'pre-Government': 0.69, 'rec-Government': 0.627273, 'f': 0.784, 'pre': 0.784, 'rec': 0.784}}
# Evaluation on dev at Epoch 8/200. Step:632/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.945813, pre-EnterSports=0.96, rec-EnterSports=0.932039, f-Economics=0.692308, pre-Economics=0.63, rec-Economics=0.768293, f-Technology=0.8, pre-Technology=0.82, rec-Technology=0.780952, f-Military=0.82, pre-Military=0.82, rec-Military=0.82, f-Government=0.657143, pre-Government=0.69, rec-Government=0.627273, f=0.784, pre=0.784, rec=0.784
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# Evaluate data in 0.24 seconds!
# 2020-07-05 02:26:39 W [callback.py:38] ======epoch : 9 , early stopping : 0/10======
# 2020-07-05 02:26:39 I [callback.py:40] metric_key : f, metric_value : 0.792
# 2020-07-05 02:26:39 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.945813, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.932039, 'f-Economics': 0.72549, 'pre-Economics': 0.74, 'rec-Economics': 0.711538, 'f-Technology': 0.776596, 'pre-Technology': 0.73, 'rec-Technology': 0.829545, 'f-Military': 0.824742, 'pre-Military': 0.8, 'rec-Military': 0.851064, 'f-Government': 0.691943, 'pre-Government': 0.73, 'rec-Government': 0.657658, 'f': 0.792, 'pre': 0.792, 'rec': 0.792}}
# Evaluation on dev at Epoch 9/200. Step:711/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.945813, pre-EnterSports=0.96, rec-EnterSports=0.932039, f-Economics=0.72549, pre-Economics=0.74, rec-Economics=0.711538, f-Technology=0.776596, pre-Technology=0.73, rec-Technology=0.829545, f-Military=0.824742, pre-Military=0.8, rec-Military=0.851064, f-Government=0.691943, pre-Government=0.73, rec-Government=0.657658, f=0.792, pre=0.792, rec=0.792
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:26:41 W [callback.py:38] ======epoch : 10 , early stopping : 0/10======
# 2020-07-05 02:26:41 I [callback.py:40] metric_key : f, metric_value : 0.792
# 2020-07-05 02:26:41 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.945274, 'pre-EnterSports': 0.95, 'rec-EnterSports': 0.940594, 'f-Economics': 0.706522, 'pre-Economics': 0.65, 'rec-Economics': 0.77381, 'f-Technology': 0.813725, 'pre-Technology': 0.83, 'rec-Technology': 0.798077, 'f-Military': 0.816327, 'pre-Military': 0.8, 'rec-Military': 0.833333, 'f-Government': 0.67907, 'pre-Government': 0.73, 'rec-Government': 0.634783, 'f': 0.792, 'pre': 0.792, 'rec': 0.792}}
# Evaluate data in 0.23 seconds!
# Evaluation on dev at Epoch 10/200. Step:790/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.945274, pre-EnterSports=0.95, rec-EnterSports=0.940594, f-Economics=0.706522, pre-Economics=0.65, rec-Economics=0.77381, f-Technology=0.813725, pre-Technology=0.83, rec-Technology=0.798077, f-Military=0.816327, pre-Military=0.8, rec-Military=0.833333, f-Government=0.67907, pre-Government=0.73, rec-Government=0.634783, f=0.792, pre=0.792, rec=0.792
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# Evaluate data in 0.24 seconds!
# 2020-07-05 02:26:43 W [callback.py:38] ======epoch : 11 , early stopping : 1/10======
# 2020-07-05 02:26:43 I [callback.py:40] metric_key : f, metric_value : 0.802
# 2020-07-05 02:26:43 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.946341, 'pre-EnterSports': 0.97, 'rec-EnterSports': 0.92381, 'f-Economics': 0.728261, 'pre-Economics': 0.67, 'rec-Economics': 0.797619, 'f-Technology': 0.813084, 'pre-Technology': 0.87, 'rec-Technology': 0.763158, 'f-Military': 0.812183, 'pre-Military': 0.8, 'rec-Military': 0.824742, 'f-Government': 0.7, 'pre-Government': 0.7, 'rec-Government': 0.7, 'f': 0.802, 'pre': 0.802, 'rec': 0.802}}
# Evaluation on dev at Epoch 11/200. Step:869/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.946341, pre-EnterSports=0.97, rec-EnterSports=0.92381, f-Economics=0.728261, pre-Economics=0.67, rec-Economics=0.797619, f-Technology=0.813084, pre-Technology=0.87, rec-Technology=0.763158, f-Military=0.812183, pre-Military=0.8, rec-Military=0.824742, f-Government=0.7, pre-Government=0.7, rec-Government=0.7, f=0.802, pre=0.802, rec=0.802
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# Evaluate data in 0.24 seconds!
# 2020-07-05 02:26:45 W [callback.py:38] ======epoch : 12 , early stopping : 0/10======
# 2020-07-05 02:26:45 I [callback.py:40] metric_key : f, metric_value : 0.808
# 2020-07-05 02:26:45 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.95, 'pre-EnterSports': 0.95, 'rec-EnterSports': 0.95, 'f-Economics': 0.75, 'pre-Economics': 0.72, 'rec-Economics': 0.782609, 'f-Technology': 0.81407, 'pre-Technology': 0.81, 'rec-Technology': 0.818182, 'f-Military': 0.825871, 'pre-Military': 0.83, 'rec-Military': 0.821782, 'f-Government': 0.701923, 'pre-Government': 0.73, 'rec-Government': 0.675926, 'f': 0.808, 'pre': 0.808, 'rec': 0.808}}
# Evaluation on dev at Epoch 12/200. Step:948/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.95, pre-EnterSports=0.95, rec-EnterSports=0.95, f-Economics=0.75, pre-Economics=0.72, rec-Economics=0.782609, f-Technology=0.81407, pre-Technology=0.81, rec-Technology=0.818182, f-Military=0.825871, pre-Military=0.83, rec-Military=0.821782, f-Government=0.701923, pre-Government=0.73, rec-Government=0.675926, f=0.808, pre=0.808, rec=0.808
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:26:47 W [callback.py:38] ======epoch : 13 , early stopping : 0/10======
# 2020-07-05 02:26:47 I [callback.py:40] metric_key : f, metric_value : 0.804
# 2020-07-05 02:26:47 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.955665, 'pre-EnterSports': 0.97, 'rec-EnterSports': 0.941748, 'f-Economics': 0.734694, 'pre-Economics': 0.72, 'rec-Economics': 0.75, 'f-Technology': 0.80597, 'pre-Technology': 0.81, 'rec-Technology': 0.80198, 'f-Military': 0.814433, 'pre-Military': 0.79, 'rec-Military': 0.840426, 'f-Government': 0.708738, 'pre-Government': 0.73, 'rec-Government': 0.688679, 'f': 0.804, 'pre': 0.804, 'rec': 0.804}}
# Evaluate data in 0.24 seconds!
# Evaluation on dev at Epoch 13/200. Step:1027/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.955665, pre-EnterSports=0.97, rec-EnterSports=0.941748, f-Economics=0.734694, pre-Economics=0.72, rec-Economics=0.75, f-Technology=0.80597, pre-Technology=0.81, rec-Technology=0.80198, f-Military=0.814433, pre-Military=0.79, rec-Military=0.840426, f-Government=0.708738, pre-Government=0.73, rec-Government=0.688679, f=0.804, pre=0.804, rec=0.804
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:26:49 W [callback.py:38] ======epoch : 14 , early stopping : 1/10======
# 2020-07-05 02:26:49 I [callback.py:40] metric_key : f, metric_value : 0.806
# 2020-07-05 02:26:49 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.955224, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.950495, 'f-Economics': 0.738462, 'pre-Economics': 0.72, 'rec-Economics': 0.757895, 'f-Technology': 0.796117, 'pre-Technology': 0.82, 'rec-Technology': 0.773585, 'f-Military': 0.818653, 'pre-Military': 0.79, 'rec-Military': 0.849462, 'f-Government': 0.721951, 'pre-Government': 0.74, 'rec-Government': 0.704762, 'f': 0.806, 'pre': 0.806, 'rec': 0.806}}
# Evaluate data in 0.23 seconds!
# Evaluation on dev at Epoch 14/200. Step:1106/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.955224, pre-EnterSports=0.96, rec-EnterSports=0.950495, f-Economics=0.738462, pre-Economics=0.72, rec-Economics=0.757895, f-Technology=0.796117, pre-Technology=0.82, rec-Technology=0.773585, f-Military=0.818653, pre-Military=0.79, rec-Military=0.849462, f-Government=0.721951, pre-Government=0.74, rec-Government=0.704762, f=0.806, pre=0.806, rec=0.806
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:26:51 W [callback.py:38] ======epoch : 15 , early stopping : 2/10======
# 2020-07-05 02:26:51 I [callback.py:40] metric_key : f, metric_value : 0.798
# 2020-07-05 02:26:51 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.955224, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.950495, 'f-Economics': 0.735751, 'pre-Economics': 0.71, 'rec-Economics': 0.763441, 'f-Technology': 0.8, 'pre-Technology': 0.8, 'rec-Technology': 0.8, 'f-Military': 0.812183, 'pre-Military': 0.8, 'rec-Military': 0.824742, 'f-Government': 0.688995, 'pre-Government': 0.72, 'rec-Government': 0.66055, 'f': 0.798, 'pre': 0.798, 'rec': 0.798}}
# Evaluate data in 0.24 seconds!
# Evaluation on dev at Epoch 15/200. Step:1185/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.955224, pre-EnterSports=0.96, rec-EnterSports=0.950495, f-Economics=0.735751, pre-Economics=0.71, rec-Economics=0.763441, f-Technology=0.8, pre-Technology=0.8, rec-Technology=0.8, f-Military=0.812183, pre-Military=0.8, rec-Military=0.824742, f-Government=0.688995, pre-Government=0.72, rec-Government=0.66055, f=0.798, pre=0.798, rec=0.798
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# Evaluate data in 0.24 seconds!
# 2020-07-05 02:26:54 W [callback.py:38] ======epoch : 16 , early stopping : 3/10======
# 2020-07-05 02:26:54 I [callback.py:40] metric_key : f, metric_value : 0.812
# 2020-07-05 02:26:54 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.955224, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.950495, 'f-Economics': 0.758974, 'pre-Economics': 0.74, 'rec-Economics': 0.778947, 'f-Technology': 0.813725, 'pre-Technology': 0.83, 'rec-Technology': 0.798077, 'f-Military': 0.824121, 'pre-Military': 0.82, 'rec-Military': 0.828283, 'f-Government': 0.706468, 'pre-Government': 0.71, 'rec-Government': 0.70297, 'f': 0.812, 'pre': 0.812, 'rec': 0.812}}
# Evaluation on dev at Epoch 16/200. Step:1264/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.955224, pre-EnterSports=0.96, rec-EnterSports=0.950495, f-Economics=0.758974, pre-Economics=0.74, rec-Economics=0.778947, f-Technology=0.813725, pre-Technology=0.83, rec-Technology=0.798077, f-Military=0.824121, pre-Military=0.82, rec-Military=0.828283, f-Government=0.706468, pre-Government=0.71, rec-Government=0.70297, f=0.812, pre=0.812, rec=0.812
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:26:56 W [callback.py:38] ======epoch : 17 , early stopping : 0/10======
# 2020-07-05 02:26:56 I [callback.py:40] metric_key : f, metric_value : 0.81
# 2020-07-05 02:26:56 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.955224, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.950495, 'f-Economics': 0.751269, 'pre-Economics': 0.74, 'rec-Economics': 0.762887, 'f-Technology': 0.8, 'pre-Technology': 0.8, 'rec-Technology': 0.8, 'f-Military': 0.834171, 'pre-Military': 0.83, 'rec-Military': 0.838384, 'f-Government': 0.70936, 'pre-Government': 0.72, 'rec-Government': 0.699029, 'f': 0.81, 'pre': 0.81, 'rec': 0.81}}
# Evaluate data in 0.24 seconds!
# Evaluation on dev at Epoch 17/200. Step:1343/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.955224, pre-EnterSports=0.96, rec-EnterSports=0.950495, f-Economics=0.751269, pre-Economics=0.74, rec-Economics=0.762887, f-Technology=0.8, pre-Technology=0.8, rec-Technology=0.8, f-Military=0.834171, pre-Military=0.83, rec-Military=0.838384, f-Government=0.70936, pre-Government=0.72, rec-Government=0.699029, f=0.81, pre=0.81, rec=0.81
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:26:58 W [callback.py:38] ======epoch : 18 , early stopping : 1/10======
# 2020-07-05 02:26:58 I [callback.py:40] metric_key : f, metric_value : 0.806
# 2020-07-05 02:26:58 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.955224, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.950495, 'f-Economics': 0.751269, 'pre-Economics': 0.74, 'rec-Economics': 0.762887, 'f-Technology': 0.79803, 'pre-Technology': 0.81, 'rec-Technology': 0.786408, 'f-Military': 0.818182, 'pre-Military': 0.81, 'rec-Military': 0.826531, 'f-Government': 0.706468, 'pre-Government': 0.71, 'rec-Government': 0.70297, 'f': 0.806, 'pre': 0.806, 'rec': 0.806}}
# Evaluate data in 0.23 seconds!
# Evaluation on dev at Epoch 18/200. Step:1422/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.955224, pre-EnterSports=0.96, rec-EnterSports=0.950495, f-Economics=0.751269, pre-Economics=0.74, rec-Economics=0.762887, f-Technology=0.79803, pre-Technology=0.81, rec-Technology=0.786408, f-Military=0.818182, pre-Military=0.81, rec-Military=0.826531, f-Government=0.706468, pre-Government=0.71, rec-Government=0.70297, f=0.806, pre=0.806, rec=0.806
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:27:00 W [callback.py:38] ======epoch : 19 , early stopping : 2/10======
# 2020-07-05 02:27:00 I [callback.py:40] metric_key : f, metric_value : 0.808
# 2020-07-05 02:27:00 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.95, 'pre-EnterSports': 0.95, 'rec-EnterSports': 0.95, 'f-Economics': 0.752577, 'pre-Economics': 0.73, 'rec-Economics': 0.776596, 'f-Technology': 0.803922, 'pre-Technology': 0.82, 'rec-Technology': 0.788462, 'f-Military': 0.824742, 'pre-Military': 0.8, 'rec-Military': 0.851064, 'f-Government': 0.711538, 'pre-Government': 0.74, 'rec-Government': 0.685185, 'f': 0.808, 'pre': 0.808, 'rec': 0.808}}
# Evaluate data in 0.23 seconds!
# Evaluation on dev at Epoch 19/200. Step:1501/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.95, pre-EnterSports=0.95, rec-EnterSports=0.95, f-Economics=0.752577, pre-Economics=0.73, rec-Economics=0.776596, f-Technology=0.803922, pre-Technology=0.82, rec-Technology=0.788462, f-Military=0.824742, pre-Military=0.8, rec-Military=0.851064, f-Government=0.711538, pre-Government=0.74, rec-Government=0.685185, f=0.808, pre=0.808, rec=0.808
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:27:02 W [callback.py:38] ======epoch : 20 , early stopping : 3/10======
# 2020-07-05 02:27:02 I [callback.py:40] metric_key : f, metric_value : 0.81
# 2020-07-05 02:27:02 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.955224, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.950495, 'f-Economics': 0.743719, 'pre-Economics': 0.74, 'rec-Economics': 0.747475, 'f-Technology': 0.803922, 'pre-Technology': 0.82, 'rec-Technology': 0.788462, 'f-Military': 0.826531, 'pre-Military': 0.81, 'rec-Military': 0.84375, 'f-Government': 0.72, 'pre-Government': 0.72, 'rec-Government': 0.72, 'f': 0.81, 'pre': 0.81, 'rec': 0.81}}
# Evaluate data in 0.23 seconds!
# Evaluation on dev at Epoch 20/200. Step:1580/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.955224, pre-EnterSports=0.96, rec-EnterSports=0.950495, f-Economics=0.743719, pre-Economics=0.74, rec-Economics=0.747475, f-Technology=0.803922, pre-Technology=0.82, rec-Technology=0.788462, f-Military=0.826531, pre-Military=0.81, rec-Military=0.84375, f-Government=0.72, pre-Government=0.72, rec-Government=0.72, f=0.81, pre=0.81, rec=0.81
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:27:04 W [callback.py:38] ======epoch : 21 , early stopping : 4/10======
# 2020-07-05 02:27:04 I [callback.py:40] metric_key : f, metric_value : 0.806
# 2020-07-05 02:27:04 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.955224, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.950495, 'f-Economics': 0.746269, 'pre-Economics': 0.75, 'rec-Economics': 0.742574, 'f-Technology': 0.8, 'pre-Technology': 0.82, 'rec-Technology': 0.780952, 'f-Military': 0.818182, 'pre-Military': 0.81, 'rec-Military': 0.826531, 'f-Government': 0.707692, 'pre-Government': 0.69, 'rec-Government': 0.726316, 'f': 0.806, 'pre': 0.806, 'rec': 0.806}}
# Evaluate data in 0.23 seconds!
# Evaluation on dev at Epoch 21/200. Step:1659/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.955224, pre-EnterSports=0.96, rec-EnterSports=0.950495, f-Economics=0.746269, pre-Economics=0.75, rec-Economics=0.742574, f-Technology=0.8, pre-Technology=0.82, rec-Technology=0.780952, f-Military=0.818182, pre-Military=0.81, rec-Military=0.826531, f-Government=0.707692, pre-Government=0.69, rec-Government=0.726316, f=0.806, pre=0.806, rec=0.806
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:27:06 W [callback.py:38] ======epoch : 22 , early stopping : 5/10======
# 2020-07-05 02:27:06 I [callback.py:40] metric_key : f, metric_value : 0.806
# 2020-07-05 02:27:06 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.941176, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.923077, 'f-Economics': 0.747368, 'pre-Economics': 0.71, 'rec-Economics': 0.788889, 'f-Technology': 0.805687, 'pre-Technology': 0.85, 'rec-Technology': 0.765766, 'f-Military': 0.824121, 'pre-Military': 0.82, 'rec-Military': 0.828283, 'f-Government': 0.704082, 'pre-Government': 0.69, 'rec-Government': 0.71875, 'f': 0.806, 'pre': 0.806, 'rec': 0.806}}
# Evaluate data in 0.23 seconds!
# Evaluation on dev at Epoch 22/200. Step:1738/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.941176, pre-EnterSports=0.96, rec-EnterSports=0.923077, f-Economics=0.747368, pre-Economics=0.71, rec-Economics=0.788889, f-Technology=0.805687, pre-Technology=0.85, rec-Technology=0.765766, f-Military=0.824121, pre-Military=0.82, rec-Military=0.828283, f-Government=0.704082, pre-Government=0.69, rec-Government=0.71875, f=0.806, pre=0.806, rec=0.806
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:27:08 W [callback.py:38] ======epoch : 23 , early stopping : 6/10======
# 2020-07-05 02:27:08 I [callback.py:40] metric_key : f, metric_value : 0.808
# 2020-07-05 02:27:08 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.955224, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.950495, 'f-Economics': 0.741117, 'pre-Economics': 0.73, 'rec-Economics': 0.752577, 'f-Technology': 0.8, 'pre-Technology': 0.82, 'rec-Technology': 0.780952, 'f-Military': 0.826531, 'pre-Military': 0.81, 'rec-Military': 0.84375, 'f-Government': 0.716418, 'pre-Government': 0.72, 'rec-Government': 0.712871, 'f': 0.808, 'pre': 0.808, 'rec': 0.808}}
# Evaluate data in 0.23 seconds!
# Evaluation on dev at Epoch 23/200. Step:1817/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.955224, pre-EnterSports=0.96, rec-EnterSports=0.950495, f-Economics=0.741117, pre-Economics=0.73, rec-Economics=0.752577, f-Technology=0.8, pre-Technology=0.82, rec-Technology=0.780952, f-Military=0.826531, pre-Military=0.81, rec-Military=0.84375, f-Government=0.716418, pre-Government=0.72, rec-Government=0.712871, f=0.808, pre=0.808, rec=0.808
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:27:10 W [callback.py:38] ======epoch : 24 , early stopping : 7/10======
# 2020-07-05 02:27:10 I [callback.py:40] metric_key : f, metric_value : 0.806
# 2020-07-05 02:27:10 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.955224, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.950495, 'f-Economics': 0.736842, 'pre-Economics': 0.7, 'rec-Economics': 0.777778, 'f-Technology': 0.8, 'pre-Technology': 0.84, 'rec-Technology': 0.763636, 'f-Military': 0.826531, 'pre-Military': 0.81, 'rec-Military': 0.84375, 'f-Government': 0.70936, 'pre-Government': 0.72, 'rec-Government': 0.699029, 'f': 0.806, 'pre': 0.806, 'rec': 0.806}}
# Evaluate data in 0.23 seconds!
# Evaluation on dev at Epoch 24/200. Step:1896/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.955224, pre-EnterSports=0.96, rec-EnterSports=0.950495, f-Economics=0.736842, pre-Economics=0.7, rec-Economics=0.777778, f-Technology=0.8, pre-Technology=0.84, rec-Technology=0.763636, f-Military=0.826531, pre-Military=0.81, rec-Military=0.84375, f-Government=0.70936, pre-Government=0.72, rec-Government=0.699029, f=0.806, pre=0.806, rec=0.806
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:27:12 W [callback.py:38] ======epoch : 25 , early stopping : 8/10======
# 2020-07-05 02:27:12 I [callback.py:40] metric_key : f, metric_value : 0.8
# 2020-07-05 02:27:12 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.950495, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.941176, 'f-Economics': 0.738916, 'pre-Economics': 0.75, 'rec-Economics': 0.728155, 'f-Technology': 0.803922, 'pre-Technology': 0.82, 'rec-Technology': 0.788462, 'f-Military': 0.81407, 'pre-Military': 0.81, 'rec-Military': 0.818182, 'f-Government': 0.6875, 'pre-Government': 0.66, 'rec-Government': 0.717391, 'f': 0.8, 'pre': 0.8, 'rec': 0.8}}
# Evaluate data in 0.24 seconds!
# Evaluation on dev at Epoch 25/200. Step:1975/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.950495, pre-EnterSports=0.96, rec-EnterSports=0.941176, f-Economics=0.738916, pre-Economics=0.75, rec-Economics=0.728155, f-Technology=0.803922, pre-Technology=0.82, rec-Technology=0.788462, f-Military=0.81407, pre-Military=0.81, rec-Military=0.818182, f-Government=0.6875, pre-Government=0.66, rec-Government=0.717391, f=0.8, pre=0.8, rec=0.8
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:27:14 W [callback.py:38] ======epoch : 26 , early stopping : 9/10======
# 2020-07-05 02:27:14 I [callback.py:40] metric_key : f, metric_value : 0.804
# 2020-07-05 02:27:14 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.955224, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.950495, 'f-Economics': 0.729167, 'pre-Economics': 0.7, 'rec-Economics': 0.76087, 'f-Technology': 0.80198, 'pre-Technology': 0.81, 'rec-Technology': 0.794118, 'f-Military': 0.830769, 'pre-Military': 0.81, 'rec-Military': 0.852632, 'f-Government': 0.704762, 'pre-Government': 0.74, 'rec-Government': 0.672727, 'f': 0.804, 'pre': 0.804, 'rec': 0.804}}
# Evaluate data in 0.23 seconds!
# Evaluation on dev at Epoch 26/200. Step:2054/15800:
# ClassifyFPreRecMetric: f-EnterSports=0.955224, pre-EnterSports=0.96, rec-EnterSports=0.950495, f-Economics=0.729167, pre-Economics=0.7, rec-Economics=0.76087, f-Technology=0.80198, pre-Technology=0.81, rec-Technology=0.794118, f-Military=0.830769, pre-Military=0.81, rec-Military=0.852632, f-Government=0.704762, pre-Government=0.74, rec-Government=0.672727, f=0.804, pre=0.804, rec=0.804
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=16.0), HTML(value='')), layout=Layout(dis…
# 2020-07-05 02:27:16 W [callback.py:38] ======epoch : 27 , early stopping : 10/10======
# 2020-07-05 02:27:16 I [callback.py:40] metric_key : f, metric_value : 0.81
# 2020-07-05 02:27:16 I [callback.py:41] eval_result :
# {'ClassifyFPreRecMetric': {'f-EnterSports': 0.955224, 'pre-EnterSports': 0.96, 'rec-EnterSports': 0.950495, 'f-Economics': 0.744898, 'pre-Economics': 0.73, 'rec-Economics': 0.760417, 'f-Technology': 0.821782, 'pre-Technology': 0.83, 'rec-Technology': 0.813725, 'f-Military': 0.825871, 'pre-Military': 0.83, 'rec-Military': 0.821782, 'f-Government': 0.7, 'pre-Government': 0.7, 'rec-Government': 0.7, 'f': 0.81, 'pre': 0.81, 'rec': 0.81}}
# 2020-07-05 02:27:16 I [callback.py:46] reach early stopping patience, stop training.
# 2020-07-05 02:27:16 I [callback.py:55] Early Stopping triggered in epoch 27!
# Evaluate data in 0.24 seconds!
# Reloaded the best model.
#
# In Epoch:16/Step:1264, got best dev performance:
# ClassifyFPreRecMetric: f-EnterSports=0.955224, pre-EnterSports=0.96, rec-EnterSports=0.950495, f-Economics=0.758974, pre-Economics=0.74, rec-Economics=0.778947, f-Technology=0.813725, pre-Technology=0.83, rec-Technology=0.798077, f-Military=0.824121, pre-Military=0.82, rec-Military=0.828283, f-Government=0.706468, pre-Government=0.71, rec-Government=0.70297, f=0.812, pre=0.812, rec=0.812
# {'best_epoch': 16,
#  'best_eval': {'ClassifyFPreRecMetric': {'f': 0.812,
#    'f-Economics': 0.758974,
#    'f-EnterSports': 0.955224,
#    'f-Government': 0.706468,
#    'f-Military': 0.824121,
#    'f-Technology': 0.813725,
#    'pre': 0.812,
#    'pre-Economics': 0.74,
#    'pre-EnterSports': 0.96,
#    'pre-Government': 0.71,
#    'pre-Military': 0.82,
#    'pre-Technology': 0.83,
#    'rec': 0.812,
#    'rec-Economics': 0.778947,
#    'rec-EnterSports': 0.950495,
#    'rec-Government': 0.70297,
#    'rec-Military': 0.828283,
#    'rec-Technology': 0.798077}},
#  'best_step': 1264,
#  'seconds': 58.42}

# %% [markdown]
# 模型预测

# %%
import torch
import os
import codecs

from fastNLP import Const
from fastNLP import DataSet
from fastNLP.core.predictor import Predictor
from myClue.tools.serialize import load_serialize_obj  # noqa
from myClue.tools.file import read_json_file_iter  # noqa

# %%
model_path = '/content/drive/My Drive/game/UCAS_NLP_TC/models/01_train_textcnn'
char_vocab_pkl_file = os.path.join(model_path, 'vocab_char.pkl')
target_vocab_pkl_file = os.path.join(model_path, 'target_char.pkl')
# 获取最新模型文件
model_list = [file_name for file_name in os.listdir(model_path) if 'best_' in file_name]
model_list.sort(key=lambda fn: os.path.getmtime(os.path.join(model_path, fn)) if not os.path.isdir(os.path.join(model_path, fn)) else 0)
model_name = os.path.join(model_path, model_list[-1])
print(model_name)
# Out:
# /content/drive/My Drive/game/UCAS_NLP_TC/models/01_train_textcnn/best_CNNText_f_2020-07-05-02-26-17-905161

# %%
logger.warn('开始加载模型')
model = torch.load(model_name)
model.eval()
logger.info('模型加载完毕:\n{}'.format(model))
logger.warn('获取词典')
char_vocab = load_serialize_obj(char_vocab_pkl_file)
logger.info('char_vocab:{}'.format(char_vocab))
target_vocab = load_serialize_obj(target_vocab_pkl_file)
logger.info('target_vocab:{}'.format(target_vocab))
logger.warn('加载测试数据')
# Out:
# 2020-07-05 02:27:16 W [<ipython-input-10-982aee047e1d>:1] 开始加载模型
# 2020-07-05 02:27:16 I [<ipython-input-10-982aee047e1d>:4] 模型加载完毕:
# CNNText(
#   (embed): Embedding(
#     (embed): StaticEmbedding(
#       (dropout_layer): Dropout(p=0, inplace=False)
#       (embedding): Embedding(96465, 50, padding_idx=0)
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (conv_pool): ConvMaxpool(
#     (convs): ModuleList(
#       (0): Conv1d(50, 30, kernel_size=(1,), stride=(1,), bias=False)
#       (1): Conv1d(50, 40, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#       (2): Conv1d(50, 50, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#     )
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=120, out_features=5, bias=True)
# )
# 2020-07-05 02:27:16 W [<ipython-input-10-982aee047e1d>:5] 获取词典
# 2020-07-05 02:27:16 I [<ipython-input-10-982aee047e1d>:7] char_vocab:Vocabulary(['近日', '，', '胡杏儿', '以', '品牌']...)
# 2020-07-05 02:27:16 I [<ipython-input-10-982aee047e1d>:9] target_vocab:Vocabulary(['EnterSports', 'Economics', 'Technology', 'Military', 'Government']...)
# 2020-07-05 02:27:16 W [<ipython-input-10-982aee047e1d>:10] 加载测试数据

# %%
predict_output_json_file_name = '/content/drive/My Drive/game/UCAS_NLP_TC/pred_data/01_train_textcnn.json'

# %%
def _white_space_split(sent):
  return sent.split(' ')

# %%
import json
predictor = Predictor(model)
with codecs.open(predict_output_json_file_name, mode='w', encoding='utf8') as fw_json:
  with codecs.open('/content/drive/My Drive/game/UCAS_NLP_TC/data/testdata.txt', mode='r', encoding='utf8') as fr:
    for line in fr:
      line = line.strip()
      if len(line) == 0:
        continue
      label, text = line.split('\t')
      test_data = [_white_space_split(text)]
      dataset = DataSet({Const.INPUT: test_data})
      dataset.add_seq_len(field_name=Const.INPUT)
      dataset.set_input(Const.INPUT, Const.INPUT_LEN)
      char_vocab.index_dataset(dataset, field_name=Const.INPUT)
      batch_output = predictor.predict(data=dataset, seq_len_field_name=Const.INPUT_LEN)
      # logger.info('batch_output : {}'.format(batch_output))
      pred_results = batch_output.get('pred')
      # logger.info('pred results:{}'.format(pred_results[:5]))
      label_id = pred_results[0]
      pred_label = target_vocab.to_word(label_id)
      # 组装成所需格式
      row_data = {}
      row_data['label'] = label
      row_data['pred_label'] = pred_label
      row_data['text'] = text
      fw_json.write('{}\n'.format(json.dumps(row_data, ensure_ascii=False)))

# %%
! head -2 /content/drive/My\ Drive/game/UCAS_NLP_TC/pred_data/01_train_textcnn.json
# Out:
# {"label": "EnterSports", "pred_label": "EnterSports", "text": "U23 亚洲杯 小组赛 第二 轮 ， 中国 U23 国家队 在 完全 占据场 上 优势 的 情况 下 ， 无奈 久 攻 不 下 ， 0-1 不敌 乌兹别克队 ， 小组赛 前 两 轮 一 胜 一 负 出场 前景 成疑 。 但 虽败犹荣 的 是 ， U23 国 足在 早早 丢球 的 情况 下 ， 并没有 自乱阵脚 ， 在 逆风 球 中 敢 打 敢 拼 ， 若 不 是 临门一脚 火候 欠缺 ， 或许 至少 能 拿到 一 分 。本 届 U23 亚洲杯 ， 在 首 战 对阵 阿曼 的 比赛 中 ， 中国队 U23 的 小伙子们 不但 取得 了 亚洲杯 历史 首 胜 ， 更 是 表现 出 难能可贵 的 精气 神儿 ， 令 人 耳目一新 。 第二 轮 对阵 乌兹别克斯坦 ， 中国 U23 国家队 迎来 真正 考验 ， 阿曼队 虽然 是 预选赛 力压 伊朗队 的 “ 黑马 ” ， 但 整体 实力 在 亚洲 难 言 一流 ， 而 乌兹别克斯坦 各 个 级别 的 国 字号 球队 都 是 中国队 的 老 对手 ， 实力 也 更 胜 一 筹 。果然 在 比赛 开始 后 仅仅 第14 分钟 ， 乌兹别克斯坦队 就 抓住 一 次 中国队 禁区 解围不当 率先 取得 领先 ， 但是 瑕不掩瑜 的 是 ， 中国队 U23 的 小伙子们 ， 在 踢 逆风 球 的 情况 下 ， 并没有 自乱阵脚 ， 而 是 展现 出 强烈 的 求 胜 欲望 ， 尤其是 下 半场 ， 比赛 的 局面 完全 被 中国队 所 掌控 ， 就 连 央视 评论员 都 感叹 这 是 一 场 中国队 的 进攻 演练 ， 无论是 杨立瑜 的 包抄 打门 ， 还是 韦世豪 的 长途 奔袭 后 的 劲射 ， 都 险些 洞穿 对手 大门 。虽然 遗憾 的 是 ， 中国队 最终 还 是 未 能 在 比赛 终场 哨声 响起 前 扳平 比分 ， 但是 从 比赛 场面 看 ， 中国队 的 年轻 小伙子们 还是 能 让 人 感受 到 一 种 积极 向上 、 敢 打 敢 拼 的 精气 神儿 ， 每 一 名 球员 都 能 为 胜利 这个 目标 心往 一 处 去 ， 劲往 一 处 使 ， 大胆 进攻 ， 渴望 胜利 ， 而 不 是 像 以往 那样 想 赢 怕 输 ， 畏手畏脚 。当然 ， 在 比赛 中 ， 年轻 的 中国 U23 国家队 还是 暴露 出 防守 中 存在 的 隐患 ， 两 场 比赛 过 后 中国队 需要 的 是 好好 总结 ， 正 如 央视 嘉宾 宫磊 所 言 ， 虽然 输球 了 ， 但 中国队 的 命运 还是 掌握在 自己 的 手 中 ， 毕竟 下轮 对阵 卡塔尔队 的 结果 将 直接 关系 到 中国 U23 国家队 能否 创造 历史 小组 出线 。 对于 这样 一 支 血气方刚 、 充满 自信 的 国家队 来 说 ， 只有 确保 出线 、 走 的 更 远 才 是 更 有利于 他们 成长 ， 因此 下轮 对阵 卡塔尔 的 比赛 才 是 对 U23 国家队 的 最大 考验 。（ 旺旺 ）"}
# {"label": "EnterSports", "pred_label": "EnterSports", "text": "网易 娱乐 12月 19日 报道 白天 不 懂夜 的 黑 ， 就 像 秀发 飘飘 的 人 永远 不 懂 秃头 的 痛 。 这 恰恰 就 是 电影 《 天气 预爆 》 中 常 远 的 内心 独白 。 在 影片 最新 发布 的 视频 中 ， 常 远 对 镜 抹生 发水 不由 悲从中来 ， 本 想 着 听听 音乐 放松 心情 ， 却 没 想到 又 遭遇 了 一万 点 的 暴击 。 如此 “ 惨烈 ” 的 画面 让 人 又 心疼 又 想 笑 。与 常 远 的 “ 忧伤 ” 相比 ， “ 宝藏 老 男孩 ” 肖央 则 显得 十分 欢脱 ， 昨日 他 与 王小利 二 人 空降 千 人 广场 舞 ， 与 当地 的 阿姨们 一起 跳上 了 电影 《 天气 预爆 》 的 “ 最灵 许愿 舞 ” ， 场面 十分 热闹 喜庆 。 除 此 之外 ， 由 人气 歌手 冯提莫 惊喜 献声 的 电影 《 天气 预爆 》 插曲 《 Super Star 》 正式 上线 ， 经典 旋律 又 现 回忆 杀 。 电影 《 天气 预爆 》 现 已 开通 预售 通道 ， 将 于 本 周五 全 国 上映 。在 电影 《 天气 预爆 》 中 ， 常 远 饰演 的 雨神人 前 是 娱乐圈 风光 的 秀发 小 王子 ， 人 后 却 是 个 秃头 ， 要 偷偷 对着 镜子 抹生 发水 。 在 最 新 的 视频 中 ， 本 就 无法 接受 自己 秃头 命运 的 雨神 更 是 频繁 被 扎心 。 因为 他 原本 想 听首 歌 排解 心 中 苦闷 ， 没 成 想 每 首 歌 都 是 “ 青春 吹动 了 你 的 长发 ” “ 黑头发 飘 起来 飘 起来 ” ， 仿佛 时刻 提醒 他 没有 头发 的 事实 。 如此 “ 悲惨 ” 又 “ 巧合 ” 的 画面 让 人 心疼 的 同时 又 忍 不 住 笑 出声 来 。素有 “ 美 男子 ” 称号 的 常 远 此 次 放下 “ 偶像 包袱 ” 挑战 起 光头 形象 ， 出乎 许多 人 的 意料 。 就 连 常 远 自己 也 十分 新奇 表示 ： “ 这 也 是 他 从小 到 大 第一 次 以 光头 的 形象 示人 ， 还 挺 难得 的 。 ” 其实 在 电影 中 ， 除了 雨神常远 有 现代 人 普遍 存在 的 脱发 毛病 外 ， 其他 的 神仙 也 都 有 一些 “ 城市 病 ” 。 像 杜鹃 饰演 的 电母 ， 就 因 浑身 带 电 无法 和 人 接触 ， 久 而 久 之 就 有 了 “ 社交 恐惧症 ” 。 这些 鲜活 真实 的 神仙 形象 与 传统 印象 中的 神仙 截然 不同 ， 这 也 是 电影 《 天气 预爆 》 独特 的 立意 之 处 ， 让 所有 人 都 能 在 电影 中 找到 共鸣 。如果 形容 常 远 是 一 个 人 对 镜 流泪 的 寂寞 ， 那么 肖央 和 王小利 便 是 千人斗舞 的 狂欢 。 昨日 ， 肖央 和 王小利 空降 哈尔滨 广场 现场 ， 与 上 千 人 一起 跳 电影 《 天气 预爆 》 的 “ 最灵 许愿舞 ” 。 欢乐 的 曲风 、 动感 的 节奏 、 灵魂 的 舞步 瞬间 点燃 了 冰城 ， 让 在场 的 所有 人 都 非常 激动 。 这 已经 不 是 肖央 第一 次 给 大家 送上 惊喜 了 。 自 影片 开启路 演 以来 ， 肖央 就 变身 “ 人形 锦鲤 ” 一路 制造 欢乐 。 作为 贺岁 档 最 强 喜剧 ， 电影 《 天气 预爆 》 也 将 在 年末 为 大家 制造 十足 “ 笑料 ” ， 开 开心 心地 迎接 2019年 。在 电影 《 天气 预爆 》 中 ， 除了 有 欢笑 、 惊喜 外 ， 观众 还 能 切实 地 感受 到 一 波 回忆 杀 。 由 冯提 莫献声 的 影片 插曲 《 Super Star 》 今日 上线 。 “ 你 是 电 ， 你 是 光 ， 你 是 唯一 的 神话 ” 的 歌词 将 马乐 （ 肖央饰 ） 与 电母 （ 杜鹃饰 ） 的 感情 描绘 地 恰 如 其 分 ， 而 “ 我 只 爱 你 ， you are my super star ” 似乎 也 对 这 段 感情 有所 暗示 。 相信 当 歌曲 经典 的 前奏 一 响起 ， 观众们 一定 会 感慨 这一 波 旋律 回忆 杀 。贺岁 最 强 喜剧 《 天气 预爆 》 预售 已经 开启 ， 将 于 2018年 12月 21日 登陆 全 国 院线 。"}

# %% [markdown]
# 结果评测

# %%
with codecs.open(predict_output_json_file_name, mode='r', encoding='utf8') as fr:
  all_count = 0
  right_count = 0
  for line in fr:
    line = line.strip()
    if len(line) == 0:
      continue
    row_data = json.loads(line)
    all_count += 1
    if row_data['label'] == row_data['pred_label']:
      right_count += 1
  print('acc:{}/{}={}'.format(right_count, all_count, round(right_count/all_count, 4)))
# Out:
# acc:402/500=0.804
