# %%
# 显卡查看
! nvidia-smi
# Out:
# Tue May 19 14:50:23 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# 依赖安装
! pip install fastNLP
# Out:
# Requirement already satisfied: fastNLP in /usr/local/lib/python3.6/dist-packages (0.5.5)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.6/dist-packages (from fastNLP) (4.41.1)
# Requirement already satisfied: nltk>=3.4.1 in /usr/local/lib/python3.6/dist-packages (from fastNLP) (3.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from fastNLP) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from fastNLP) (2019.12.20)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from fastNLP) (1.5.0+cu101)
# Requirement already satisfied: prettytable>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from fastNLP) (0.7.2)
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (from fastNLP) (2.2.4)
# Requirement already satisfied: numpy>=1.14.2 in /usr/local/lib/python3.6/dist-packages (from fastNLP) (1.18.4)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from nltk>=3.4.1->fastNLP) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from nltk>=3.4.1->fastNLP) (0.14.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->fastNLP) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->fastNLP) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->fastNLP) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->fastNLP) (2.9)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.0->fastNLP) (0.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (46.3.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (2.0.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (3.0.2)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (1.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastNLP) (0.6.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy->fastNLP) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy->fastNLP) (3.1.0)

# %% [markdown]
# 加载数据集

# %%
import sys

from fastNLP.core import Const
from fastNLP.io import PeopleDailyNERLoader
from fastNLP.io import PeopleDailyPipe

sys.path.insert(0, '/content/drive/My Drive/my_framework/qyt_clue/')  # 定义搜索路径的优先顺序，序号从0开始，表示最大优先级

import myClue  # noqa
print('myClue module path :{}'.format(myClue.__file__))  # 输出测试模块文件位置
from myClue.core import logger  # noqa
from myClue.core.utils import print_data_bundle  # noqa
from myClue.tools.serialize import save_serialize_obj  # noqa
# Out:
# myClue module path :/content/drive/My Drive/my_framework/qyt_clue/myClue/__init__.py

# %%
train_file_config = {
    'train': '/content/drive/My Drive/my_framework/qyt_clue/data/peopledaily/train.txt',
    'dev': '/content/drive/My Drive/my_framework/qyt_clue/data/peopledaily/dev.txt',
    'test': '/content/drive/My Drive/my_framework/qyt_clue/data/peopledaily/test.txt',
}
# train_data_bundle_pkl_file = './data/peopledaily/train_data_bundle.pkl'
logger.info('数据加载')
data_loader = PeopleDailyNERLoader()
data_bundle = data_loader.load(train_file_config)
print_data_bundle(data_bundle)
logger.info('数据预处理')
data_pipe = PeopleDailyPipe()
data_bundle = data_pipe.process(data_bundle)
data_bundle.rename_field(field_name=Const.CHAR_INPUT, new_field_name=Const.INPUT, ignore_miss_dataset=True, rename_vocab=True)
print_data_bundle(data_bundle)
# save_serialize_obj(data_bundle, train_data_bundle_pkl_file)
# logger.info('数据预处理后进行序列化：{}'.format(train_data_bundle_pkl_file))
# Out:
# 2020-05-19 14:50:32 I [<ipython-input-4-21f59d70dedd>:7] 数据加载
# 2020-05-19 14:50:33 I [utils.py:16] dataset name : train
# 2020-05-19 14:50:33 I [utils.py:17] dataset len : 20864
# 2020-05-19 14:50:33 I [utils.py:18] dataset example :
# 2020-05-19 14:50:33 I [utils.py:19]
# +------------------------------------------+------------------------------------------+
# | raw_chars                                | target                                   |
# +------------------------------------------+------------------------------------------+
# | ['海', '钓', '比', '赛', '地', '点', ... | ['O', 'O', 'O', 'O', 'O', 'O', 'O', '... |
# | ['这', '座', '依', '山', '傍', '水', ... | ['O', 'O', 'O', 'O', 'O', 'O', 'O', '... |
# | ['但', '作', '为', '一', '个', '共', ... | ['O', 'O', 'O', 'O', 'O', 'O', 'O', '... |
# | ['在', '发', '达', '国', '家', '，', ... | ['O', 'O', 'O', 'O', 'O', 'O', 'O', '... |
# | ['日', '俄', '两', '国', '国', '内', ... | ['B-LOC', 'B-LOC', 'O', 'O', 'O', 'O'... |
# +------------------------------------------+------------------------------------------+
# 2020-05-19 14:50:33 I [utils.py:20] dataset 输出各个field的被设置成input和target的情况 :
# 2020-05-19 14:50:33 I [utils.py:21]
# +-------------+-----------+--------+
# | field_names | raw_chars | target |
# +-------------+-----------+--------+
# |   is_input  |   False   | False  |
# |  is_target  |   False   | False  |
# | ignore_type |           |        |
# |  pad_value  |           |        |
# +-------------+-----------+--------+
# 2020-05-19 14:50:33 I [utils.py:16] dataset name : dev
# 2020-05-19 14:50:33 I [utils.py:17] dataset len : 2318
# 2020-05-19 14:50:33 I [utils.py:18] dataset example :
# 2020-05-19 14:50:33 I [utils.py:19]
# +------------------------------------------+------------------------------------------+
# | raw_chars                                | target                                   |
# +------------------------------------------+------------------------------------------+
# | ['在', '这', '里', '恕', '弟', '不', ... | ['O', 'O', 'O', 'O', 'O', 'O', 'O', '... |
# | ['相', '比', '之', '下', '，', '青', ... | ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'I... |
# | ['理', '由', '多', '多', '，', '最', ... | ['O', 'O', 'O', 'O', 'O', 'O', 'O', '... |
# | ['分', '工', '，', '各', '有', '各', ... | ['O', 'O', 'O', 'O', 'O', 'O', 'O', '... |
# | ['胡', '老', '说', '，', '当', '画', ... | ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O... |
# +------------------------------------------+------------------------------------------+
# 2020-05-19 14:50:33 I [utils.py:20] dataset 输出各个field的被设置成input和target的情况 :
# 2020-05-19 14:50:33 I [utils.py:21]
# +-------------+-----------+--------+
# | field_names | raw_chars | target |
# +-------------+-----------+--------+
# |   is_input  |   False   | False  |
# |  is_target  |   False   | False  |
# | ignore_type |           |        |
# |  pad_value  |           |        |
# +-------------+-----------+--------+
# 2020-05-19 14:50:33 I [utils.py:16] dataset name : test
# 2020-05-19 14:50:33 I [utils.py:17] dataset len : 4636
# 2020-05-19 14:50:33 I [utils.py:18] dataset example :
# 2020-05-19 14:50:33 I [utils.py:19]
# +------------------------------------------+------------------------------------------+
# | raw_chars                                | target                                   |
# +------------------------------------------+------------------------------------------+
# | ['我', '们', '变', '而', '以', '书', ... | ['O', 'O', 'O', 'O', 'O', 'O', 'O', '... |
# | ['为', '了', '跟', '踪', '国', '际', ... | ['O', 'O', 'O', 'O', 'O', 'O', 'O', '... |
# | ['其', '中', '线', '装', '古', '籍', ... | ['O', 'O', 'O', 'O', 'O', 'O', 'O', '... |
# | ['有', '的', '古', '木', '交', '柯', ... | ['O', 'O', 'O', 'O', 'O', 'O', 'O', '... |
# | ['不', '过', '重', '在', '晋', '趣', ... | ['O', 'O', 'O', 'O', 'O', 'O', 'O', '... |
# +------------------------------------------+------------------------------------------+
# 2020-05-19 14:50:33 I [utils.py:20] dataset 输出各个field的被设置成input和target的情况 :
# 2020-05-19 14:50:33 I [utils.py:21]
# +-------------+-----------+--------+
# | field_names | raw_chars | target |
# +-------------+-----------+--------+
# |   is_input  |   False   | False  |
# |  is_target  |   False   | False  |
# | ignore_type |           |        |
# |  pad_value  |           |        |
# +-------------+-----------+--------+
# 2020-05-19 14:50:33 I [<ipython-input-4-21f59d70dedd>:11] 数据预处理
# +-------------+-----------+--------+
# | field_names | raw_chars | target |
# +-------------+-----------+--------+
# |   is_input  |   False   | False  |
# |  is_target  |   False   | False  |
# | ignore_type |           |        |
# |  pad_value  |           |        |
# +-------------+-----------+--------+
# +-------------+-----------+--------+
# | field_names | raw_chars | target |
# +-------------+-----------+--------+
# |   is_input  |   False   | False  |
# |  is_target  |   False   | False  |
# | ignore_type |           |        |
# |  pad_value  |           |        |
# +-------------+-----------+--------+
# +-------------+-----------+--------+
# | field_names | raw_chars | target |
# +-------------+-----------+--------+
# |   is_input  |   False   | False  |
# |  is_target  |   False   | False  |
# | ignore_type |           |        |
# |  pad_value  |           |        |
# +-------------+-----------+--------+
# 2020-05-19 14:50:42 I [utils.py:16] dataset name : train
# 2020-05-19 14:50:42 I [utils.py:17] dataset len : 20864
# 2020-05-19 14:50:42 I [utils.py:18] dataset example :
# 2020-05-19 14:50:42 I [utils.py:19]
# +------------------------+------------------------+---------+------------------------+
# | raw_chars              | target                 | seq_len | words                  |
# +------------------------+------------------------+---------+------------------------+
# | ['海', '钓', '比', ... | [0, 0, 0, 0, 0, 0, ... | 18      | [234, 1636, 154, 14... |
# | ['这', '座', '依', ... | [0, 0, 0, 0, 0, 0, ... | 35      | [24, 753, 663, 278,... |
# | ['但', '作', '为', ... | [0, 0, 0, 0, 0, 0, ... | 88      | [225, 29, 19, 6, 27... |
# | ['在', '发', '达', ... | [0, 0, 0, 0, 0, 0, ... | 32      | [8, 26, 256, 5, 37,... |
# | ['日', '俄', '两', ... | [3, 3, 0, 0, 0, 0, ... | 40      | [34, 628, 130, 5, 5... |
# +------------------------+------------------------+---------+------------------------+
# 2020-05-19 14:50:42 I [utils.py:20] dataset 输出各个field的被设置成input和target的情况 :
# 2020-05-19 14:50:42 I [utils.py:21]
# +-------------+-----------+--------+---------+-------+
# | field_names | raw_chars | target | seq_len | words |
# +-------------+-----------+--------+---------+-------+
# |   is_input  |   False   |  True  |   True  |  True |
# |  is_target  |   False   |  True  |   True  | False |
# | ignore_type |           | False  |  False  | False |
# |  pad_value  |           |   0    |    0    |   0   |
# +-------------+-----------+--------+---------+-------+
# 2020-05-19 14:50:42 I [utils.py:16] dataset name : dev
# 2020-05-19 14:50:42 I [utils.py:17] dataset len : 2318
# 2020-05-19 14:50:42 I [utils.py:18] dataset example :
# 2020-05-19 14:50:42 I [utils.py:19]
# +------------------------+------------------------+---------+------------------------+
# | raw_chars              | target                 | seq_len | words                  |
# +------------------------+------------------------+---------+------------------------+
# | ['在', '这', '里', ... | [0, 0, 0, 0, 0, 0, ... | 69      | [8, 24, 142, 2942, ... |
# | ['相', '比', '之', ... | [0, 0, 0, 0, 0, 5, ... | 35      | [244, 154, 113, 67,... |
# | ['理', '由', '多', ... | [0, 0, 0, 0, 0, 0, ... | 54      | [61, 198, 44, 44, 2... |
# | ['分', '工', '，', ... | [0, 0, 0, 0, 0, 0, ... | 56      | [76, 47, 2, 188, 14... |
# | ['胡', '老', '说', ... | [6, 0, 0, 0, 0, 0, ... | 70      | [924, 320, 86, 2, 1... |
# +------------------------+------------------------+---------+------------------------+
# 2020-05-19 14:50:42 I [utils.py:20] dataset 输出各个field的被设置成input和target的情况 :
# 2020-05-19 14:50:42 I [utils.py:21]
# +-------------+-----------+--------+---------+-------+
# | field_names | raw_chars | target | seq_len | words |
# +-------------+-----------+--------+---------+-------+
# |   is_input  |   False   |  True  |   True  |  True |
# |  is_target  |   False   |  True  |   True  | False |
# | ignore_type |           | False  |  False  | False |
# |  pad_value  |           |   0    |    0    |   0   |
# +-------------+-----------+--------+---------+-------+
# 2020-05-19 14:50:42 I [utils.py:16] dataset name : test
# 2020-05-19 14:50:42 I [utils.py:17] dataset len : 4636
# 2020-05-19 14:50:42 I [utils.py:18] dataset example :
# 2020-05-19 14:50:42 I [utils.py:19]
# +------------------------+------------------------+---------+------------------------+
# | raw_chars              | target                 | seq_len | words                  |
# +------------------------+------------------------+---------+------------------------+
# | ['我', '们', '变', ... | [0, 0, 0, 0, 0, 0, ... | 40      | [53, 49, 352, 109, ... |
# | ['为', '了', '跟', ... | [0, 0, 0, 0, 0, 0, ... | 39      | [19, 10, 1250, 1837... |
# | ['其', '中', '线', ... | [0, 0, 0, 0, 0, 0, ... | 43      | [152, 9, 524, 584, ... |
# | ['有', '的', '古', ... | [0, 0, 0, 0, 0, 0, ... | 32      | [14, 3, 570, 936, 2... |
# | ['不', '过', '重', ... | [0, 0, 0, 0, 0, 0, ... | 28      | [17, 104, 91, 8, 18... |
# +------------------------+------------------------+---------+------------------------+
# 2020-05-19 14:50:42 I [utils.py:20] dataset 输出各个field的被设置成input和target的情况 :
# 2020-05-19 14:50:42 I [utils.py:21]
# +-------------+-----------+--------+---------+-------+
# | field_names | raw_chars | target | seq_len | words |
# +-------------+-----------+--------+---------+-------+
# |   is_input  |   False   |  True  |   True  |  True |
# |  is_target  |   False   |  True  |   True  | False |
# | ignore_type |           | False  |  False  | False |
# |  pad_value  |           |   0    |    0    |   0   |
# +-------------+-----------+--------+---------+-------+
# +-------------+-----------+--------+---------+-------+
# | field_names | raw_chars | target | seq_len | words |
# +-------------+-----------+--------+---------+-------+
# |   is_input  |   False   |  True  |   True  |  True |
# |  is_target  |   False   |  True  |   True  | False |
# | ignore_type |           | False  |  False  | False |
# |  pad_value  |           |   0    |    0    |   0   |
# +-------------+-----------+--------+---------+-------+
# +-------------+-----------+--------+---------+-------+
# | field_names | raw_chars | target | seq_len | words |
# +-------------+-----------+--------+---------+-------+
# |   is_input  |   False   |  True  |   True  |  True |
# |  is_target  |   False   |  True  |   True  | False |
# | ignore_type |           | False  |  False  | False |
# |  pad_value  |           |   0    |    0    |   0   |
# +-------------+-----------+--------+---------+-------+
# +-------------+-----------+--------+---------+-------+
# | field_names | raw_chars | target | seq_len | words |
# +-------------+-----------+--------+---------+-------+
# |   is_input  |   False   |  True  |   True  |  True |
# |  is_target  |   False   |  True  |   True  | False |
# | ignore_type |           | False  |  False  | False |
# |  pad_value  |           |   0    |    0    |   0   |
# +-------------+-----------+--------+---------+-------+

# %% [markdown]
# 模型训练

# %%
import os
import sys
import time

import torch

from fastNLP import Const
from fastNLP.embeddings import StaticEmbedding
from fastNLP.models import BiLSTMCRF
from fastNLP import SpanFPreRecMetric
from fastNLP import Trainer
from fastNLP import LossInForward
from torch.optim import Adam
from fastNLP import Tester

from myClue.core import logger  # noqa
from myClue.core.callback import EarlyStopCallback  # noqa
from myClue.tools.serialize import load_serialize_obj  # noqa
from myClue.tools.serialize import save_serialize_obj  # noqa
from myClue.tools.file import init_file_path  # noqa

# %%
# train_data_bundle_pkl_file = '/content/drive/My Drive/my_framework/qyt_clue/data/peopledaily/train_data_bundle.pkl'
model_path = '/content/drive/My Drive/my_framework/qyt_clue/data/peopledaily/model_bilstm_crf'
init_file_path(model_path)
logger.add_file_handler(os.path.join(model_path, 'log_{}.txt'.format(time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime()))))  # 日志写入文件
char_vocab_pkl_file = os.path.join(model_path, 'vocab_char.pkl')
target_vocab_pkl_file = os.path.join(model_path, 'target_char.pkl')
# logger.warn('加载数据集')
# data_bundle = load_serialize_obj(train_data_bundle_pkl_file)
logger.warn('获取词典')
char_vocab = data_bundle.get_vocab('words')
logger.info('char_vocab:{}'.format(char_vocab))
target_vocab = data_bundle.get_vocab('target')
logger.info('target_vocab:{}'.format(target_vocab))
save_serialize_obj(char_vocab, char_vocab_pkl_file)
save_serialize_obj(target_vocab, target_vocab_pkl_file)
logger.info('词典序列化:{}'.format(char_vocab_pkl_file))
logger.warn('选择预训练词向量')
word2vec_embed = StaticEmbedding(char_vocab, model_dir_or_name='/content/drive/My Drive/data/cn_char_fastnlp_100d/cn_char_fastnlp_100d.txt')
logger.warn('神经网络模型')
model = BiLSTMCRF(embed=word2vec_embed, num_classes=len(target_vocab), num_layers=1, hidden_size=200, dropout=0.5,
                  target_vocab=target_vocab)
logger.info(model)
logger.warn('训练超参数设定')
loss = LossInForward()
optimizer = Adam([param for param in model.parameters() if param.requires_grad])
# metric = AccuracyMetric()
metric = SpanFPreRecMetric(tag_vocab=data_bundle.get_vocab(Const.TARGET), only_gross=False)  # 若only_gross=False, 即还会返回各个label的metric统计值
device = 'cuda' if torch.cuda.is_available() else 'cpu'  # 如果有gpu的话在gpu上运行，训练速度会更快
logger.info('device:{}'.format(device))
# Out:
# 2020-05-19 14:50:42 W [<ipython-input-6-145b57519a35>:9] 获取词典
# 2020-05-19 14:50:42 I [<ipython-input-6-145b57519a35>:11] char_vocab:Vocabulary(['海', '钓', '比', '赛', '地']...)
# 2020-05-19 14:50:42 I [<ipython-input-6-145b57519a35>:13] target_vocab:Vocabulary(['O', 'B-LOC', 'I-LOC', 'B-PER', 'I-PER']...)
# 2020-05-19 14:50:42 I [<ipython-input-6-145b57519a35>:16] 词典序列化:/content/drive/My Drive/my_framework/qyt_clue/data/peopledaily/model_bilstm_crf/vocab_char.pkl
# 2020-05-19 14:50:42 W [<ipython-input-6-145b57519a35>:17] 选择预训练词向量
# /pytorch/aten/src/ATen/native/TensorFactories.cpp:361: UserWarning: Deprecation warning: In a future PyTorch release torch.full will no longer return tensors of floating dtype by default. Instead, a bool fill_value will return a tensor of torch.bool dtype, and an integral fill_value will return a tensor of torch.long dtype. Set the optional `dtype` or `out` arguments to suppress this warning.
# 2020-05-19 14:50:44 W [<ipython-input-6-145b57519a35>:19] 神经网络模型
# 2020-05-19 14:50:44 I [<ipython-input-6-145b57519a35>:22] BiLSTMCRF(
#   (embed): StaticEmbedding(
#     (dropout_layer): Dropout(p=0, inplace=False)
#     (embedding): Embedding(4464, 100, padding_idx=0)
#   )
#   (lstm): LSTM(
#     (lstm): LSTM(100, 200, batch_first=True, bidirectional=True)
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=400, out_features=7, bias=True)
#   (crf): ConditionalRandomField()
# )
# 2020-05-19 14:50:44 W [<ipython-input-6-145b57519a35>:23] 训练超参数设定
# 2020-05-19 14:50:44 I [<ipython-input-6-145b57519a35>:29] device:cuda
# Found 4455 out of 4467 words in the pre-training embedding.

# %%
batch_size = 32
n_epochs = 200
early_stopping = 10
trainer = Trainer(
    save_path=model_path,
    train_data=data_bundle.get_dataset('train'),
    model=model,
    loss=loss,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epochs=n_epochs,
    dev_data=data_bundle.get_dataset('dev'),
    metrics=metric,
    metric_key='f',
    device=device,
    callbacks=[EarlyStopCallback(early_stopping)])
logger.warn('开始训练')
trainer.train()
logger.warn('训练后评估')
tester = Tester(data=data_bundle.get_dataset('test'), model=model, metrics=metric, batch_size=64, device=device)
test_result = tester.test()
logger.info('评估结果：\n{}'.format(test_result))
# Out:
# input fields after batch(if batch size is 2):
# 	target: (1)type:torch.Tensor (2)dtype:torch.int64, (3)shape:torch.Size([2, 35])
# 	seq_len: (1)type:torch.Tensor (2)dtype:torch.int64, (3)shape:torch.Size([2])
# 	words: (1)type:torch.Tensor (2)dtype:torch.int64, (3)shape:torch.Size([2, 35])
# target fields after batch(if batch size is 2):
# 	target: (1)type:torch.Tensor (2)dtype:torch.int64, (3)shape:torch.Size([2, 35])
# 	seq_len: (1)type:torch.Tensor (2)dtype:torch.int64, (3)shape:torch.Size([2])
# 2020-05-19 14:50:53 W [<ipython-input-7-a0a0304e06bd>:17] 开始训练
# training epochs started 2020-05-19-14-50-53-048389
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=130400.0), HTML(value='')), layout=Layout…
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 14:53:05 W [callback.py:38] ======epoch : 1 , early stopping : 0/10======
# 2020-05-19 14:53:05 I [callback.py:40] metric_key : f, metric_value : 0.592813
# 2020-05-19 14:53:05 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.505457, 'pre-org': 0.581242, 'rec-org': 0.447154, 'f-per': 0.680272, 'pre-per': 0.853242, 'rec-per': 0.565611, 'f-loc': 0.599489, 'pre-loc': 0.671756, 'rec-loc': 0.541261, 'f': 0.592813, 'pre': 0.684734, 'rec': 0.52265}}
# Evaluate data in 6.17 seconds!
# Evaluation on dev at Epoch 1/200. Step:652/130400:
# SpanFPreRecMetric: f-org=0.505457, pre-org=0.581242, rec-org=0.447154, f-per=0.680272, pre-per=0.853242, rec-per=0.565611, f-loc=0.599489, pre-loc=0.671756, rec-loc=0.541261, f=0.592813, pre=0.684734, rec=0.52265
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 14:55:17 W [callback.py:38] ======epoch : 2 , early stopping : 0/10======
# 2020-05-19 14:55:17 I [callback.py:40] metric_key : f, metric_value : 0.680142
# 2020-05-19 14:55:17 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.592066, 'pre-org': 0.70922, 'rec-org': 0.50813, 'f-per': 0.777116, 'pre-per': 0.821159, 'rec-per': 0.737557, 'f-loc': 0.676048, 'pre-loc': 0.789726, 'rec-loc': 0.590979, 'f': 0.680142, 'pre': 0.778979, 'rec': 0.603561}}
# Evaluate data in 6.3 seconds!
# Evaluation on dev at Epoch 2/200. Step:1304/130400:
# SpanFPreRecMetric: f-org=0.592066, pre-org=0.70922, rec-org=0.50813, f-per=0.777116, pre-per=0.821159, rec-per=0.737557, f-loc=0.676048, pre-loc=0.789726, rec-loc=0.590979, f=0.680142, pre=0.778979, rec=0.603561
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 14:57:31 W [callback.py:38] ======epoch : 3 , early stopping : 0/10======
# 2020-05-19 14:57:31 I [callback.py:40] metric_key : f, metric_value : 0.727273
# 2020-05-19 14:57:31 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.649503, 'pre-org': 0.765517, 'rec-org': 0.564024, 'f-per': 0.81407, 'pre-per': 0.915254, 'rec-per': 0.733032, 'f-loc': 0.725774, 'pre-loc': 0.814413, 'rec-loc': 0.654536, 'f': 0.727273, 'pre': 0.826391, 'rec': 0.649385}}
# Evaluate data in 6.52 seconds!
# Evaluation on dev at Epoch 3/200. Step:1956/130400:
# SpanFPreRecMetric: f-org=0.649503, pre-org=0.765517, rec-org=0.564024, f-per=0.81407, pre-per=0.915254, rec-per=0.733032, f-loc=0.725774, pre-loc=0.814413, rec-loc=0.654536, f=0.727273, pre=0.826391, rec=0.649385
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 14:59:45 W [callback.py:38] ======epoch : 4 , early stopping : 0/10======
# 2020-05-19 14:59:45 I [callback.py:40] metric_key : f, metric_value : 0.772337
# 2020-05-19 14:59:45 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.702139, 'pre-org': 0.762813, 'rec-org': 0.650407, 'f-per': 0.838557, 'pre-per': 0.878563, 'rec-per': 0.802036, 'f-loc': 0.776642, 'pre-loc': 0.817564, 'rec-loc': 0.739621, 'f': 0.772337, 'pre': 0.818528, 'rec': 0.731081}}
# Evaluate data in 6.25 seconds!
# Evaluation on dev at Epoch 4/200. Step:2608/130400:
# SpanFPreRecMetric: f-org=0.702139, pre-org=0.762813, rec-org=0.650407, f-per=0.838557, pre-per=0.878563, rec-per=0.802036, f-loc=0.776642, pre-loc=0.817564, rec-loc=0.739621, f=0.772337, pre=0.818528, rec=0.731081
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:01:58 W [callback.py:38] ======epoch : 5 , early stopping : 0/10======
# 2020-05-19 15:01:58 I [callback.py:40] metric_key : f, metric_value : 0.783772
# 2020-05-19 15:01:58 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.696512, 'pre-org': 0.813859, 'rec-org': 0.60874, 'f-per': 0.836096, 'pre-per': 0.914094, 'rec-per': 0.770362, 'f-loc': 0.801067, 'pre-loc': 0.834908, 'rec-loc': 0.769862, 'f': 0.783772, 'pre': 0.848171, 'rec': 0.728463}}
# Evaluate data in 6.14 seconds!
# Evaluation on dev at Epoch 5/200. Step:3260/130400:
# SpanFPreRecMetric: f-org=0.696512, pre-org=0.813859, rec-org=0.60874, f-per=0.836096, pre-per=0.914094, rec-per=0.770362, f-loc=0.801067, pre-loc=0.834908, rec-loc=0.769862, f=0.783772, pre=0.848171, rec=0.728463
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:04:11 W [callback.py:38] ======epoch : 6 , early stopping : 0/10======
# 2020-05-19 15:04:11 I [callback.py:40] metric_key : f, metric_value : 0.801458
# 2020-05-19 15:04:11 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.729619, 'pre-org': 0.862691, 'rec-org': 0.632114, 'f-per': 0.848338, 'pre-per': 0.910506, 'rec-per': 0.794118, 'f-loc': 0.813362, 'pre-loc': 0.842394, 'rec-loc': 0.786263, 'f': 0.801458, 'pre': 0.862662, 'rec': 0.748363}}
# Evaluate data in 6.2 seconds!
# Evaluation on dev at Epoch 6/200. Step:3912/130400:
# SpanFPreRecMetric: f-org=0.729619, pre-org=0.862691, rec-org=0.632114, f-per=0.848338, pre-per=0.910506, rec-per=0.794118, f-loc=0.813362, pre-loc=0.842394, rec-loc=0.786263, f=0.801458, pre=0.862662, rec=0.748363
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:06:23 W [callback.py:38] ======epoch : 7 , early stopping : 0/10======
# 2020-05-19 15:06:23 I [callback.py:40] metric_key : f, metric_value : 0.818629
# 2020-05-19 15:06:23 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.75645, 'pre-org': 0.768344, 'rec-org': 0.744919, 'f-per': 0.860177, 'pre-per': 0.89889, 'rec-per': 0.824661, 'f-loc': 0.832204, 'pre-loc': 0.883199, 'rec-loc': 0.786776, 'f': 0.818629, 'pre': 0.855552, 'rec': 0.78476}}
# Evaluate data in 6.16 seconds!
# Evaluation on dev at Epoch 7/200. Step:4564/130400:
# SpanFPreRecMetric: f-org=0.75645, pre-org=0.768344, rec-org=0.744919, f-per=0.860177, pre-per=0.89889, rec-per=0.824661, f-loc=0.832204, pre-loc=0.883199, rec-loc=0.786776, f=0.818629, pre=0.855552, rec=0.78476
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:08:35 W [callback.py:38] ======epoch : 8 , early stopping : 0/10======
# 2020-05-19 15:08:35 I [callback.py:40] metric_key : f, metric_value : 0.828313
# 2020-05-19 15:08:35 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.771163, 'pre-org': 0.83353, 'rec-org': 0.71748, 'f-per': 0.864256, 'pre-per': 0.907846, 'rec-per': 0.824661, 'f-loc': 0.839937, 'pre-loc': 0.866485, 'rec-loc': 0.814967, 'f': 0.828313, 'pre': 0.868006, 'rec': 0.792092}}
# Evaluate data in 6.2 seconds!
# Evaluation on dev at Epoch 8/200. Step:5216/130400:
# SpanFPreRecMetric: f-org=0.771163, pre-org=0.83353, rec-org=0.71748, f-per=0.864256, pre-per=0.907846, rec-per=0.824661, f-loc=0.839937, pre-loc=0.866485, rec-loc=0.814967, f=0.828313, pre=0.868006, rec=0.792092
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:10:48 W [callback.py:38] ======epoch : 9 , early stopping : 0/10======
# 2020-05-19 15:10:48 I [callback.py:40] metric_key : f, metric_value : 0.835931
# 2020-05-19 15:10:48 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.783483, 'pre-org': 0.81768, 'rec-org': 0.752033, 'f-per': 0.864169, 'pre-per': 0.895631, 'rec-per': 0.834842, 'f-loc': 0.84961, 'pre-loc': 0.894111, 'rec-loc': 0.809329, 'f': 0.835931, 'pre': 0.874678, 'rec': 0.800471}}
# Evaluate data in 6.26 seconds!
# Evaluation on dev at Epoch 9/200. Step:5868/130400:
# SpanFPreRecMetric: f-org=0.783483, pre-org=0.81768, rec-org=0.752033, f-per=0.864169, pre-per=0.895631, rec-per=0.834842, f-loc=0.84961, pre-loc=0.894111, rec-loc=0.809329, f=0.835931, pre=0.874678, rec=0.800471
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:13:03 W [callback.py:38] ======epoch : 10 , early stopping : 0/10======
# 2020-05-19 15:13:03 I [callback.py:40] metric_key : f, metric_value : 0.846362
# 2020-05-19 15:13:03 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.792316, 'pre-org': 0.809979, 'rec-org': 0.775407, 'f-per': 0.866235, 'pre-per': 0.904059, 'rec-per': 0.831448, 'f-loc': 0.865023, 'pre-loc': 0.896154, 'rec-loc': 0.835982, 'f': 0.846362, 'pre': 0.875245, 'rec': 0.819324}}
# Evaluate data in 6.24 seconds!
# Evaluation on dev at Epoch 10/200. Step:6520/130400:
# SpanFPreRecMetric: f-org=0.792316, pre-org=0.809979, rec-org=0.775407, f-per=0.866235, pre-per=0.904059, rec-per=0.831448, f-loc=0.865023, pre-loc=0.896154, rec-loc=0.835982, f=0.846362, pre=0.875245, rec=0.819324
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:15:13 W [callback.py:38] ======epoch : 11 , early stopping : 0/10======
# 2020-05-19 15:15:13 I [callback.py:40] metric_key : f, metric_value : 0.846884
# 2020-05-19 15:15:13 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.785518, 'pre-org': 0.853397, 'rec-org': 0.727642, 'f-per': 0.873156, 'pre-per': 0.912454, 'rec-per': 0.837104, 'f-loc': 0.864836, 'pre-loc': 0.901111, 'rec-loc': 0.831369, 'f': 0.846884, 'pre': 0.892174, 'rec': 0.80597}}
# Evaluate data in 6.23 seconds!
# Evaluation on dev at Epoch 11/200. Step:7172/130400:
# SpanFPreRecMetric: f-org=0.785518, pre-org=0.853397, rec-org=0.727642, f-per=0.873156, pre-per=0.912454, rec-per=0.837104, f-loc=0.864836, pre-loc=0.901111, rec-loc=0.831369, f=0.846884, pre=0.892174, rec=0.80597
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:17:24 W [callback.py:38] ======epoch : 12 , early stopping : 0/10======
# 2020-05-19 15:17:24 I [callback.py:40] metric_key : f, metric_value : 0.84811
# 2020-05-19 15:17:24 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.799134, 'pre-org': 0.855156, 'rec-org': 0.75, 'f-per': 0.872555, 'pre-per': 0.916563, 'rec-per': 0.832579, 'f-loc': 0.861267, 'pre-loc': 0.9, 'rec-loc': 0.82573, 'f': 0.84811, 'pre': 0.89265, 'rec': 0.807803}}
# Evaluate data in 6.01 seconds!
# Evaluation on dev at Epoch 12/200. Step:7824/130400:
# SpanFPreRecMetric: f-org=0.799134, pre-org=0.855156, rec-org=0.75, f-per=0.872555, pre-per=0.916563, rec-per=0.832579, f-loc=0.861267, pre-loc=0.9, rec-loc=0.82573, f=0.84811, pre=0.89265, rec=0.807803
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:19:37 W [callback.py:38] ======epoch : 13 , early stopping : 0/10======
# 2020-05-19 15:19:37 I [callback.py:40] metric_key : f, metric_value : 0.85065
# 2020-05-19 15:19:37 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.78346, 'pre-org': 0.843091, 'rec-org': 0.731707, 'f-per': 0.875366, 'pre-per': 0.906667, 'rec-per': 0.846154, 'f-loc': 0.872272, 'pre-loc': 0.907028, 'rec-loc': 0.840082, 'f': 0.85065, 'pre': 0.891279, 'rec': 0.813564}}
# Evaluate data in 6.15 seconds!
# Evaluation on dev at Epoch 13/200. Step:8476/130400:
# SpanFPreRecMetric: f-org=0.78346, pre-org=0.843091, rec-org=0.731707, f-per=0.875366, pre-per=0.906667, rec-per=0.846154, f-loc=0.872272, pre-loc=0.907028, rec-loc=0.840082, f=0.85065, pre=0.891279, rec=0.813564
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:21:48 W [callback.py:38] ======epoch : 14 , early stopping : 0/10======
# 2020-05-19 15:21:48 I [callback.py:40] metric_key : f, metric_value : 0.859136
# 2020-05-19 15:21:48 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.808533, 'pre-org': 0.828358, 'rec-org': 0.789634, 'f-per': 0.87123, 'pre-per': 0.894048, 'rec-per': 0.849548, 'f-loc': 0.879202, 'pre-loc': 0.901454, 'rec-loc': 0.858022, 'f': 0.859136, 'pre': 0.88088, 'rec': 0.838439}}
# Evaluate data in 6.18 seconds!
# Evaluation on dev at Epoch 14/200. Step:9128/130400:
# SpanFPreRecMetric: f-org=0.808533, pre-org=0.828358, rec-org=0.789634, f-per=0.87123, pre-per=0.894048, rec-per=0.849548, f-loc=0.879202, pre-loc=0.901454, rec-loc=0.858022, f=0.859136, pre=0.88088, rec=0.838439
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:24:03 W [callback.py:38] ======epoch : 15 , early stopping : 0/10======
# 2020-05-19 15:24:03 I [callback.py:40] metric_key : f, metric_value : 0.857028
# 2020-05-19 15:24:03 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.797475, 'pre-org': 0.826609, 'rec-org': 0.770325, 'f-per': 0.875854, 'pre-per': 0.881881, 'rec-per': 0.86991, 'f-loc': 0.878087, 'pre-loc': 0.900809, 'rec-loc': 0.856484, 'f': 0.857028, 'pre': 0.877607, 'rec': 0.837392}}
# Evaluate data in 6.21 seconds!
# Evaluation on dev at Epoch 15/200. Step:9780/130400:
# SpanFPreRecMetric: f-org=0.797475, pre-org=0.826609, rec-org=0.770325, f-per=0.875854, pre-per=0.881881, rec-per=0.86991, f-loc=0.878087, pre-loc=0.900809, rec-loc=0.856484, f=0.857028, pre=0.877607, rec=0.837392
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:26:15 W [callback.py:38] ======epoch : 16 , early stopping : 1/10======
# 2020-05-19 15:26:15 I [callback.py:40] metric_key : f, metric_value : 0.860701
# 2020-05-19 15:26:15 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.811291, 'pre-org': 0.835307, 'rec-org': 0.788618, 'f-per': 0.884863, 'pre-per': 0.915357, 'rec-per': 0.856335, 'f-loc': 0.874834, 'pre-loc': 0.908389, 'rec-loc': 0.84367, 'f': 0.860701, 'pre': 0.890975, 'rec': 0.832417}}
# Evaluate data in 6.22 seconds!
# Evaluation on dev at Epoch 16/200. Step:10432/130400:
# SpanFPreRecMetric: f-org=0.811291, pre-org=0.835307, rec-org=0.788618, f-per=0.884863, pre-per=0.915357, rec-per=0.856335, f-loc=0.874834, pre-loc=0.908389, rec-loc=0.84367, f=0.860701, pre=0.890975, rec=0.832417
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:28:28 W [callback.py:38] ======epoch : 17 , early stopping : 0/10======
# 2020-05-19 15:28:28 I [callback.py:40] metric_key : f, metric_value : 0.863715
# 2020-05-19 15:28:28 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.809979, 'pre-org': 0.847778, 'rec-org': 0.775407, 'f-per': 0.880702, 'pre-per': 0.911622, 'rec-per': 0.85181, 'f-loc': 0.882098, 'pre-loc': 0.876518, 'rec-loc': 0.88775, 'f': 0.863715, 'pre': 0.877364, 'rec': 0.850484}}
# Evaluate data in 6.34 seconds!
# Evaluation on dev at Epoch 17/200. Step:11084/130400:
# SpanFPreRecMetric: f-org=0.809979, pre-org=0.847778, rec-org=0.775407, f-per=0.880702, pre-per=0.911622, rec-per=0.85181, f-loc=0.882098, pre-loc=0.876518, rec-loc=0.88775, f=0.863715, pre=0.877364, rec=0.850484
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:30:41 W [callback.py:38] ======epoch : 18 , early stopping : 0/10======
# 2020-05-19 15:30:41 I [callback.py:40] metric_key : f, metric_value : 0.860172
# 2020-05-19 15:30:41 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.796628, 'pre-org': 0.827133, 'rec-org': 0.768293, 'f-per': 0.877294, 'pre-per': 0.889535, 'rec-per': 0.865385, 'f-loc': 0.88399, 'pre-loc': 0.905863, 'rec-loc': 0.863147, 'f': 0.860172, 'pre': 0.882191, 'rec': 0.839225}}
# Evaluate data in 6.18 seconds!
# Evaluation on dev at Epoch 18/200. Step:11736/130400:
# SpanFPreRecMetric: f-org=0.796628, pre-org=0.827133, rec-org=0.768293, f-per=0.877294, pre-per=0.889535, rec-per=0.865385, f-loc=0.88399, pre-loc=0.905863, rec-loc=0.863147, f=0.860172, pre=0.882191, rec=0.839225
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:32:51 W [callback.py:38] ======epoch : 19 , early stopping : 1/10======
# 2020-05-19 15:32:51 I [callback.py:40] metric_key : f, metric_value : 0.858847
# 2020-05-19 15:32:51 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.787188, 'pre-org': 0.844988, 'rec-org': 0.736789, 'f-per': 0.882421, 'pre-per': 0.908873, 'rec-per': 0.857466, 'f-loc': 0.882831, 'pre-loc': 0.903433, 'rec-loc': 0.863147, 'f': 0.858847, 'pre': 0.890607, 'rec': 0.829275}}
# Evaluate data in 5.95 seconds!
# Evaluation on dev at Epoch 19/200. Step:12388/130400:
# SpanFPreRecMetric: f-org=0.787188, pre-org=0.844988, rec-org=0.736789, f-per=0.882421, pre-per=0.908873, rec-per=0.857466, f-loc=0.882831, pre-loc=0.903433, rec-loc=0.863147, f=0.858847, pre=0.890607, rec=0.829275
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:35:00 W [callback.py:38] ======epoch : 20 , early stopping : 2/10======
# 2020-05-19 15:35:00 I [callback.py:40] metric_key : f, metric_value : 0.859915
# 2020-05-19 15:35:00 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.79773, 'pre-org': 0.810273, 'rec-org': 0.785569, 'f-per': 0.880047, 'pre-per': 0.911515, 'rec-per': 0.850679, 'f-loc': 0.882125, 'pre-loc': 0.88785, 'rec-loc': 0.876474, 'f': 0.859915, 'pre': 0.873144, 'rec': 0.84708}}
# Evaluate data in 6.13 seconds!
# Evaluation on dev at Epoch 20/200. Step:13040/130400:
# SpanFPreRecMetric: f-org=0.79773, pre-org=0.810273, rec-org=0.785569, f-per=0.880047, pre-per=0.911515, rec-per=0.850679, f-loc=0.882125, pre-loc=0.88785, rec-loc=0.876474, f=0.859915, pre=0.873144, rec=0.84708
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:37:13 W [callback.py:38] ======epoch : 21 , early stopping : 3/10======
# 2020-05-19 15:37:13 I [callback.py:40] metric_key : f, metric_value : 0.86305
# 2020-05-19 15:37:13 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.791255, 'pre-org': 0.811099, 'rec-org': 0.772358, 'f-per': 0.891815, 'pre-per': 0.902665, 'rec-per': 0.881222, 'f-loc': 0.886243, 'pre-loc': 0.915801, 'rec-loc': 0.858534, 'f': 0.86305, 'pre': 0.885643, 'rec': 0.841582}}
# Evaluate data in 6.15 seconds!
# Evaluation on dev at Epoch 21/200. Step:13692/130400:
# SpanFPreRecMetric: f-org=0.791255, pre-org=0.811099, rec-org=0.772358, f-per=0.891815, pre-per=0.902665, rec-per=0.881222, f-loc=0.886243, pre-loc=0.915801, rec-loc=0.858534, f=0.86305, pre=0.885643, rec=0.841582
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:39:25 W [callback.py:38] ======epoch : 22 , early stopping : 4/10======
# 2020-05-19 15:39:25 I [callback.py:40] metric_key : f, metric_value : 0.864378
# 2020-05-19 15:39:25 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.799796, 'pre-org': 0.803901, 'rec-org': 0.795732, 'f-per': 0.890427, 'pre-per': 0.908235, 'rec-per': 0.873303, 'f-loc': 0.885484, 'pre-loc': 0.897368, 'rec-loc': 0.873911, 'f': 0.864378, 'pre': 0.875403, 'rec': 0.853627}}
# Evaluate data in 6.24 seconds!
# Evaluation on dev at Epoch 22/200. Step:14344/130400:
# SpanFPreRecMetric: f-org=0.799796, pre-org=0.803901, rec-org=0.795732, f-per=0.890427, pre-per=0.908235, rec-per=0.873303, f-loc=0.885484, pre-loc=0.897368, rec-loc=0.873911, f=0.864378, pre=0.875403, rec=0.853627
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:41:39 W [callback.py:38] ======epoch : 23 , early stopping : 0/10======
# 2020-05-19 15:41:39 I [callback.py:40] metric_key : f, metric_value : 0.867463
# 2020-05-19 15:41:39 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.804393, 'pre-org': 0.828664, 'rec-org': 0.781504, 'f-per': 0.893148, 'pre-per': 0.917661, 'rec-per': 0.86991, 'f-loc': 0.88749, 'pre-loc': 0.9087, 'rec-loc': 0.867248, 'f': 0.867463, 'pre': 0.890298, 'rec': 0.845771}}
# Evaluate data in 6.19 seconds!
# Evaluation on dev at Epoch 23/200. Step:14996/130400:
# SpanFPreRecMetric: f-org=0.804393, pre-org=0.828664, rec-org=0.781504, f-per=0.893148, pre-per=0.917661, rec-per=0.86991, f-loc=0.88749, pre-loc=0.9087, rec-loc=0.867248, f=0.867463, pre=0.890298, rec=0.845771
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:43:54 W [callback.py:38] ======epoch : 24 , early stopping : 0/10======
# 2020-05-19 15:43:54 I [callback.py:40] metric_key : f, metric_value : 0.867131
# 2020-05-19 15:43:54 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.803313, 'pre-org': 0.818565, 'rec-org': 0.788618, 'f-per': 0.892669, 'pre-per': 0.926918, 'rec-per': 0.86086, 'f-loc': 0.88796, 'pre-loc': 0.905218, 'rec-loc': 0.871348, 'f': 0.867131, 'pre': 0.887579, 'rec': 0.847604}}
# Evaluate data in 6.25 seconds!
# Evaluation on dev at Epoch 24/200. Step:15648/130400:
# SpanFPreRecMetric: f-org=0.803313, pre-org=0.818565, rec-org=0.788618, f-per=0.892669, pre-per=0.926918, rec-per=0.86086, f-loc=0.88796, pre-loc=0.905218, rec-loc=0.871348, f=0.867131, pre=0.887579, rec=0.847604
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:46:06 W [callback.py:38] ======epoch : 25 , early stopping : 1/10======
# 2020-05-19 15:46:06 I [callback.py:40] metric_key : f, metric_value : 0.867057
# 2020-05-19 15:46:06 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.815776, 'pre-org': 0.83351, 'rec-org': 0.79878, 'f-per': 0.885038, 'pre-per': 0.904368, 'rec-per': 0.866516, 'f-loc': 0.884576, 'pre-loc': 0.893361, 'rec-loc': 0.875961, 'f': 0.867057, 'pre': 0.880637, 'rec': 0.853888}}
# Evaluate data in 6.11 seconds!
# Evaluation on dev at Epoch 25/200. Step:16300/130400:
# SpanFPreRecMetric: f-org=0.815776, pre-org=0.83351, rec-org=0.79878, f-per=0.885038, pre-per=0.904368, rec-per=0.866516, f-loc=0.884576, pre-loc=0.893361, rec-loc=0.875961, f=0.867057, pre=0.880637, rec=0.853888
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:48:17 W [callback.py:38] ======epoch : 26 , early stopping : 2/10======
# 2020-05-19 15:48:17 I [callback.py:40] metric_key : f, metric_value : 0.85956
# 2020-05-19 15:48:17 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.785677, 'pre-org': 0.815301, 'rec-org': 0.75813, 'f-per': 0.879765, 'pre-per': 0.91352, 'rec-per': 0.848416, 'f-loc': 0.887097, 'pre-loc': 0.900687, 'rec-loc': 0.873911, 'f': 0.85956, 'pre': 0.882061, 'rec': 0.838178}}
# Evaluate data in 6.01 seconds!
# Evaluation on dev at Epoch 26/200. Step:16952/130400:
# SpanFPreRecMetric: f-org=0.785677, pre-org=0.815301, rec-org=0.75813, f-per=0.879765, pre-per=0.91352, rec-per=0.848416, f-loc=0.887097, pre-loc=0.900687, rec-loc=0.873911, f=0.85956, pre=0.882061, rec=0.838178
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:50:26 W [callback.py:38] ======epoch : 27 , early stopping : 3/10======
# 2020-05-19 15:50:26 I [callback.py:40] metric_key : f, metric_value : 0.8646
# 2020-05-19 15:50:26 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.802686, 'pre-org': 0.816176, 'rec-org': 0.789634, 'f-per': 0.881917, 'pre-per': 0.889528, 'rec-per': 0.874434, 'f-loc': 0.887795, 'pre-loc': 0.897799, 'rec-loc': 0.878011, 'f': 0.8646, 'pre': 0.875034, 'rec': 0.854412}}
# Evaluate data in 6.1 seconds!
# Evaluation on dev at Epoch 27/200. Step:17604/130400:
# SpanFPreRecMetric: f-org=0.802686, pre-org=0.816176, rec-org=0.789634, f-per=0.881917, pre-per=0.889528, rec-per=0.874434, f-loc=0.887795, pre-loc=0.897799, rec-loc=0.878011, f=0.8646, pre=0.875034, rec=0.854412
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:52:38 W [callback.py:38] ======epoch : 28 , early stopping : 4/10======
# 2020-05-19 15:52:38 I [callback.py:40] metric_key : f, metric_value : 0.866916
# 2020-05-19 15:52:38 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.804992, 'pre-org': 0.824281, 'rec-org': 0.786585, 'f-per': 0.881733, 'pre-per': 0.913835, 'rec-per': 0.85181, 'f-loc': 0.891254, 'pre-loc': 0.902734, 'rec-loc': 0.880062, 'f': 0.866916, 'pre': 0.88513, 'rec': 0.849437}}
# Evaluate data in 6.1 seconds!
# Evaluation on dev at Epoch 28/200. Step:18256/130400:
# SpanFPreRecMetric: f-org=0.804992, pre-org=0.824281, rec-org=0.786585, f-per=0.881733, pre-per=0.913835, rec-per=0.85181, f-loc=0.891254, pre-loc=0.902734, rec-loc=0.880062, f=0.866916, pre=0.88513, rec=0.849437
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:54:47 W [callback.py:38] ======epoch : 29 , early stopping : 5/10======
# 2020-05-19 15:54:47 I [callback.py:40] metric_key : f, metric_value : 0.864705
# 2020-05-19 15:54:47 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.798942, 'pre-org': 0.833333, 'rec-org': 0.767276, 'f-per': 0.87931, 'pre-per': 0.893692, 'rec-per': 0.865385, 'f-loc': 0.890637, 'pre-loc': 0.911923, 'rec-loc': 0.870323, 'f': 0.864705, 'pre': 0.887969, 'rec': 0.842629}}
# Evaluate data in 6.02 seconds!
# Evaluation on dev at Epoch 29/200. Step:18908/130400:
# SpanFPreRecMetric: f-org=0.798942, pre-org=0.833333, rec-org=0.767276, f-per=0.87931, pre-per=0.893692, rec-per=0.865385, f-loc=0.890637, pre-loc=0.911923, rec-loc=0.870323, f=0.864705, pre=0.887969, rec=0.842629
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:56:57 W [callback.py:38] ======epoch : 30 , early stopping : 6/10======
# 2020-05-19 15:56:57 I [callback.py:40] metric_key : f, metric_value : 0.864707
# 2020-05-19 15:56:57 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.792627, 'pre-org': 0.798762, 'rec-org': 0.786585, 'f-per': 0.891705, 'pre-per': 0.908451, 'rec-per': 0.875566, 'f-loc': 0.889004, 'pre-loc': 0.897597, 'rec-loc': 0.880574, 'f': 0.864707, 'pre': 0.874431, 'rec': 0.855198}}
# Evaluate data in 6.17 seconds!
# Evaluation on dev at Epoch 30/200. Step:19560/130400:
# SpanFPreRecMetric: f-org=0.792627, pre-org=0.798762, rec-org=0.786585, f-per=0.891705, pre-per=0.908451, rec-per=0.875566, f-loc=0.889004, pre-loc=0.897597, rec-loc=0.880574, f=0.864707, pre=0.874431, rec=0.855198
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 15:59:09 W [callback.py:38] ======epoch : 31 , early stopping : 7/10======
# 2020-05-19 15:59:09 I [callback.py:40] metric_key : f, metric_value : 0.873804
# 2020-05-19 15:59:09 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.817204, 'pre-org': 0.823529, 'rec-org': 0.810976, 'f-per': 0.893148, 'pre-per': 0.917661, 'rec-per': 0.86991, 'f-loc': 0.893849, 'pre-loc': 0.905363, 'rec-loc': 0.882624, 'f': 0.873804, 'pre': 0.886762, 'rec': 0.86122}}
# Evaluate data in 6.12 seconds!
# Evaluation on dev at Epoch 31/200. Step:20212/130400:
# SpanFPreRecMetric: f-org=0.817204, pre-org=0.823529, rec-org=0.810976, f-per=0.893148, pre-per=0.917661, rec-per=0.86991, f-loc=0.893849, pre-loc=0.905363, rec-loc=0.882624, f=0.873804, pre=0.886762, rec=0.86122
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:01:18 W [callback.py:38] ======epoch : 32 , early stopping : 0/10======
# 2020-05-19 16:01:18 I [callback.py:40] metric_key : f, metric_value : 0.863219
# 2020-05-19 16:01:18 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.796899, 'pre-org': 0.810726, 'rec-org': 0.783537, 'f-per': 0.884793, 'pre-per': 0.901408, 'rec-per': 0.868778, 'f-loc': 0.886812, 'pre-loc': 0.898474, 'rec-loc': 0.875448, 'f': 0.863219, 'pre': 0.87662, 'rec': 0.850223}}
# Evaluate data in 5.96 seconds!
# Evaluation on dev at Epoch 32/200. Step:20864/130400:
# SpanFPreRecMetric: f-org=0.796899, pre-org=0.810726, rec-org=0.783537, f-per=0.884793, pre-per=0.901408, rec-per=0.868778, f-loc=0.886812, pre-loc=0.898474, rec-loc=0.875448, f=0.863219, pre=0.87662, rec=0.850223
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:03:27 W [callback.py:38] ======epoch : 33 , early stopping : 1/10======
# 2020-05-19 16:03:27 I [callback.py:40] metric_key : f, metric_value : 0.86424
# 2020-05-19 16:03:27 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.801226, 'pre-org': 0.805755, 'rec-org': 0.796748, 'f-per': 0.889147, 'pre-per': 0.912992, 'rec-per': 0.866516, 'f-loc': 0.885135, 'pre-loc': 0.897733, 'rec-loc': 0.872886, 'f': 0.86424, 'pre': 0.877056, 'rec': 0.851794}}
# Evaluate data in 5.97 seconds!
# Evaluation on dev at Epoch 33/200. Step:21516/130400:
# SpanFPreRecMetric: f-org=0.801226, pre-org=0.805755, rec-org=0.796748, f-per=0.889147, pre-per=0.912992, rec-per=0.866516, f-loc=0.885135, pre-loc=0.897733, rec-loc=0.872886, f=0.86424, pre=0.877056, rec=0.851794
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:05:34 W [callback.py:38] ======epoch : 34 , early stopping : 2/10======
# 2020-05-19 16:05:34 I [callback.py:40] metric_key : f, metric_value : 0.867616
# 2020-05-19 16:05:34 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.79878, 'pre-org': 0.79878, 'rec-org': 0.79878, 'f-per': 0.893125, 'pre-per': 0.912633, 'rec-per': 0.874434, 'f-loc': 0.89112, 'pre-loc': 0.895036, 'rec-loc': 0.887237, 'f': 0.867616, 'pre': 0.873838, 'rec': 0.861482}}
# Evaluate data in 5.96 seconds!
# Evaluation on dev at Epoch 34/200. Step:22168/130400:
# SpanFPreRecMetric: f-org=0.79878, pre-org=0.79878, rec-org=0.79878, f-per=0.893125, pre-per=0.912633, rec-per=0.874434, f-loc=0.89112, pre-loc=0.895036, rec-loc=0.887237, f=0.867616, pre=0.873838, rec=0.861482
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:07:43 W [callback.py:38] ======epoch : 35 , early stopping : 3/10======
# 2020-05-19 16:07:43 I [callback.py:40] metric_key : f, metric_value : 0.868859
# 2020-05-19 16:07:43 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.805236, 'pre-org': 0.830454, 'rec-org': 0.781504, 'f-per': 0.882319, 'pre-per': 0.886857, 'rec-per': 0.877828, 'f-loc': 0.894326, 'pre-loc': 0.908514, 'rec-loc': 0.880574, 'f': 0.868859, 'pre': 0.883803, 'rec': 0.854412}}
# Evaluate data in 5.9 seconds!
# Evaluation on dev at Epoch 35/200. Step:22820/130400:
# SpanFPreRecMetric: f-org=0.805236, pre-org=0.830454, rec-org=0.781504, f-per=0.882319, pre-per=0.886857, rec-per=0.877828, f-loc=0.894326, pre-loc=0.908514, rec-loc=0.880574, f=0.868859, pre=0.883803, rec=0.854412
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:09:49 W [callback.py:38] ======epoch : 36 , early stopping : 4/10======
# 2020-05-19 16:09:49 I [callback.py:40] metric_key : f, metric_value : 0.866054
# 2020-05-19 16:09:49 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.792689, 'pre-org': 0.815252, 'rec-org': 0.771341, 'f-per': 0.89186, 'pre-per': 0.917464, 'rec-per': 0.867647, 'f-loc': 0.8909, 'pre-loc': 0.8988, 'rec-loc': 0.883137, 'f': 0.866054, 'pre': 0.881922, 'rec': 0.850746}}
# Evaluate data in 5.9 seconds!
# Evaluation on dev at Epoch 36/200. Step:23472/130400:
# SpanFPreRecMetric: f-org=0.792689, pre-org=0.815252, rec-org=0.771341, f-per=0.89186, pre-per=0.917464, rec-per=0.867647, f-loc=0.8909, pre-loc=0.8988, rec-loc=0.883137, f=0.866054, pre=0.881922, rec=0.850746
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:11:56 W [callback.py:38] ======epoch : 37 , early stopping : 5/10======
# 2020-05-19 16:11:56 I [callback.py:40] metric_key : f, metric_value : 0.867261
# 2020-05-19 16:11:56 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.790339, 'pre-org': 0.799376, 'rec-org': 0.781504, 'f-per': 0.894919, 'pre-per': 0.913915, 'rec-per': 0.876697, 'f-loc': 0.893817, 'pre-loc': 0.910202, 'rec-loc': 0.878011, 'f': 0.867261, 'pre': 0.882178, 'rec': 0.852841}}
# Evaluate data in 5.81 seconds!
# Evaluation on dev at Epoch 37/200. Step:24124/130400:
# SpanFPreRecMetric: f-org=0.790339, pre-org=0.799376, rec-org=0.781504, f-per=0.894919, pre-per=0.913915, rec-per=0.876697, f-loc=0.893817, pre-loc=0.910202, rec-loc=0.878011, f=0.867261, pre=0.882178, rec=0.852841
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:14:01 W [callback.py:38] ======epoch : 38 , early stopping : 6/10======
# 2020-05-19 16:14:01 I [callback.py:40] metric_key : f, metric_value : 0.87702
# 2020-05-19 16:14:01 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.821762, 'pre-org': 0.838266, 'rec-org': 0.805894, 'f-per': 0.892734, 'pre-per': 0.910588, 'rec-per': 0.875566, 'f-loc': 0.897778, 'pre-loc': 0.916222, 'rec-loc': 0.880062, 'f': 0.87702, 'pre': 0.894823, 'rec': 0.859911}}
# Evaluate data in 5.85 seconds!
# Evaluation on dev at Epoch 38/200. Step:24776/130400:
# SpanFPreRecMetric: f-org=0.821762, pre-org=0.838266, rec-org=0.805894, f-per=0.892734, pre-per=0.910588, rec-per=0.875566, f-loc=0.897778, pre-loc=0.916222, rec-loc=0.880062, f=0.87702, pre=0.894823, rec=0.859911
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:16:07 W [callback.py:38] ======epoch : 39 , early stopping : 0/10======
# 2020-05-19 16:16:07 I [callback.py:40] metric_key : f, metric_value : 0.870005
# 2020-05-19 16:16:07 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.809176, 'pre-org': 0.830835, 'rec-org': 0.788618, 'f-per': 0.882695, 'pre-per': 0.906921, 'rec-per': 0.859729, 'f-loc': 0.894519, 'pre-loc': 0.902452, 'rec-loc': 0.886725, 'f': 0.870005, 'pre': 0.885335, 'rec': 0.855198}}
# Evaluate data in 5.89 seconds!
# Evaluation on dev at Epoch 39/200. Step:25428/130400:
# SpanFPreRecMetric: f-org=0.809176, pre-org=0.830835, rec-org=0.788618, f-per=0.882695, pre-per=0.906921, rec-per=0.859729, f-loc=0.894519, pre-loc=0.902452, rec-loc=0.886725, f=0.870005, pre=0.885335, rec=0.855198
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:18:13 W [callback.py:38] ======epoch : 40 , early stopping : 1/10======
# 2020-05-19 16:18:13 I [callback.py:40] metric_key : f, metric_value : 0.867845
# 2020-05-19 16:18:13 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.816199, 'pre-org': 0.834395, 'rec-org': 0.79878, 'f-per': 0.87791, 'pre-per': 0.881414, 'rec-per': 0.874434, 'f-loc': 0.888832, 'pre-loc': 0.890432, 'rec-loc': 0.887237, 'f': 0.867845, 'pre': 0.874302, 'rec': 0.861482}}
# Evaluate data in 5.89 seconds!
# Evaluation on dev at Epoch 40/200. Step:26080/130400:
# SpanFPreRecMetric: f-org=0.816199, pre-org=0.834395, rec-org=0.79878, f-per=0.87791, pre-per=0.881414, rec-per=0.874434, f-loc=0.888832, pre-loc=0.890432, rec-loc=0.887237, f=0.867845, pre=0.874302, rec=0.861482
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:20:19 W [callback.py:38] ======epoch : 41 , early stopping : 2/10======
# 2020-05-19 16:20:19 I [callback.py:40] metric_key : f, metric_value : 0.86793
# 2020-05-19 16:20:19 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.805071, 'pre-org': 0.838284, 'rec-org': 0.77439, 'f-per': 0.889782, 'pre-per': 0.903263, 'rec-per': 0.876697, 'f-loc': 0.888605, 'pre-loc': 0.885889, 'rec-loc': 0.891338, 'f': 0.86793, 'pre': 0.878284, 'rec': 0.857816}}
# Evaluate data in 5.86 seconds!
# Evaluation on dev at Epoch 41/200. Step:26732/130400:
# SpanFPreRecMetric: f-org=0.805071, pre-org=0.838284, rec-org=0.77439, f-per=0.889782, pre-per=0.903263, rec-per=0.876697, f-loc=0.888605, pre-loc=0.885889, rec-loc=0.891338, f=0.86793, pre=0.878284, rec=0.857816
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:22:24 W [callback.py:38] ======epoch : 42 , early stopping : 3/10======
# 2020-05-19 16:22:24 I [callback.py:40] metric_key : f, metric_value : 0.868015
# 2020-05-19 16:22:24 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.804113, 'pre-org': 0.813736, 'rec-org': 0.794715, 'f-per': 0.889018, 'pre-per': 0.913978, 'rec-per': 0.865385, 'f-loc': 0.890909, 'pre-loc': 0.903107, 'rec-loc': 0.879036, 'f': 0.868015, 'pre': 0.882337, 'rec': 0.85415}}
# Evaluate data in 5.83 seconds!
# Evaluation on dev at Epoch 42/200. Step:27384/130400:
# SpanFPreRecMetric: f-org=0.804113, pre-org=0.813736, rec-org=0.794715, f-per=0.889018, pre-per=0.913978, rec-per=0.865385, f-loc=0.890909, pre-loc=0.903107, rec-loc=0.879036, f=0.868015, pre=0.882337, rec=0.85415
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:24:29 W [callback.py:38] ======epoch : 43 , early stopping : 4/10======
# 2020-05-19 16:24:29 I [callback.py:40] metric_key : f, metric_value : 0.863004
# 2020-05-19 16:24:29 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.797867, 'pre-org': 0.839506, 'rec-org': 0.760163, 'f-per': 0.87935, 'pre-per': 0.902381, 'rec-per': 0.857466, 'f-loc': 0.887664, 'pre-loc': 0.909629, 'rec-loc': 0.866735, 'f': 0.863004, 'pre': 0.890529, 'rec': 0.83713}}
# Evaluate data in 5.85 seconds!
# Evaluation on dev at Epoch 43/200. Step:28036/130400:
# SpanFPreRecMetric: f-org=0.797867, pre-org=0.839506, rec-org=0.760163, f-per=0.87935, pre-per=0.902381, rec-per=0.857466, f-loc=0.887664, pre-loc=0.909629, rec-loc=0.866735, f=0.863004, pre=0.890529, rec=0.83713
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:26:33 W [callback.py:38] ======epoch : 44 , early stopping : 5/10======
# 2020-05-19 16:26:33 I [callback.py:40] metric_key : f, metric_value : 0.867191
# 2020-05-19 16:26:33 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.801474, 'pre-org': 0.831694, 'rec-org': 0.773374, 'f-per': 0.884075, 'pre-per': 0.916262, 'rec-per': 0.854072, 'f-loc': 0.891795, 'pre-loc': 0.892252, 'rec-loc': 0.891338, 'f': 0.867191, 'pre': 0.882592, 'rec': 0.852317}}
# Evaluate data in 5.78 seconds!
# Evaluation on dev at Epoch 44/200. Step:28688/130400:
# SpanFPreRecMetric: f-org=0.801474, pre-org=0.831694, rec-org=0.773374, f-per=0.884075, pre-per=0.916262, rec-per=0.854072, f-loc=0.891795, pre-loc=0.892252, rec-loc=0.891338, f=0.867191, pre=0.882592, rec=0.852317
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:28:38 W [callback.py:38] ======epoch : 45 , early stopping : 6/10======
# 2020-05-19 16:28:38 I [callback.py:40] metric_key : f, metric_value : 0.867879
# 2020-05-19 16:28:38 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.804303, 'pre-org': 0.81095, 'rec-org': 0.797764, 'f-per': 0.887986, 'pre-per': 0.9118, 'rec-per': 0.865385, 'f-loc': 0.891079, 'pre-loc': 0.901837, 'rec-loc': 0.880574, 'f': 0.867879, 'pre': 0.880388, 'rec': 0.855721}}
# Evaluate data in 5.91 seconds!
# Evaluation on dev at Epoch 45/200. Step:29340/130400:
# SpanFPreRecMetric: f-org=0.804303, pre-org=0.81095, rec-org=0.797764, f-per=0.887986, pre-per=0.9118, rec-per=0.865385, f-loc=0.891079, pre-loc=0.901837, rec-loc=0.880574, f=0.867879, pre=0.880388, rec=0.855721
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:30:43 W [callback.py:38] ======epoch : 46 , early stopping : 7/10======
# 2020-05-19 16:30:43 I [callback.py:40] metric_key : f, metric_value : 0.868106
# 2020-05-19 16:30:43 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.807996, 'pre-org': 0.837514, 'rec-org': 0.780488, 'f-per': 0.89261, 'pre-per': 0.911557, 'rec-per': 0.874434, 'f-loc': 0.886651, 'pre-loc': 0.89334, 'rec-loc': 0.880062, 'f': 0.868106, 'pre': 0.883645, 'rec': 0.853103}}
# Evaluate data in 5.92 seconds!
# Evaluation on dev at Epoch 46/200. Step:29992/130400:
# SpanFPreRecMetric: f-org=0.807996, pre-org=0.837514, rec-org=0.780488, f-per=0.89261, pre-per=0.911557, rec-per=0.874434, f-loc=0.886651, pre-loc=0.89334, rec-loc=0.880062, f=0.868106, pre=0.883645, rec=0.853103
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:32:49 W [callback.py:38] ======epoch : 47 , early stopping : 8/10======
# 2020-05-19 16:32:49 I [callback.py:40] metric_key : f, metric_value : 0.867163
# 2020-05-19 16:32:49 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.803133, 'pre-org': 0.825994, 'rec-org': 0.781504, 'f-per': 0.883801, 'pre-per': 0.894554, 'rec-per': 0.873303, 'f-loc': 0.891361, 'pre-loc': 0.899739, 'rec-loc': 0.883137, 'f': 0.867163, 'pre': 0.880022, 'rec': 0.854674}}
# Evaluate data in 5.84 seconds!
# Evaluation on dev at Epoch 47/200. Step:30644/130400:
# SpanFPreRecMetric: f-org=0.803133, pre-org=0.825994, rec-org=0.781504, f-per=0.883801, pre-per=0.894554, rec-per=0.873303, f-loc=0.891361, pre-loc=0.899739, rec-loc=0.883137, f=0.867163, pre=0.880022, rec=0.854674
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:34:54 W [callback.py:38] ======epoch : 48 , early stopping : 9/10======
# 2020-05-19 16:34:54 I [callback.py:40] metric_key : f, metric_value : 0.866764
# 2020-05-19 16:34:54 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.803313, 'pre-org': 0.818565, 'rec-org': 0.788618, 'f-per': 0.886047, 'pre-per': 0.911483, 'rec-per': 0.861991, 'f-loc': 0.889925, 'pre-loc': 0.899476, 'rec-loc': 0.880574, 'f': 0.866764, 'pre': 0.881429, 'rec': 0.852579}}
# Evaluate data in 5.9 seconds!
# Evaluation on dev at Epoch 48/200. Step:31296/130400:
# SpanFPreRecMetric: f-org=0.803313, pre-org=0.818565, rec-org=0.788618, f-per=0.886047, pre-per=0.911483, rec-per=0.861991, f-loc=0.889925, pre-loc=0.899476, rec-loc=0.880574, f=0.866764, pre=0.881429, rec=0.852579
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:37:00 W [callback.py:38] ======epoch : 49 , early stopping : 10/10======
# 2020-05-19 16:37:00 I [callback.py:40] metric_key : f, metric_value : 0.862476
# 2020-05-19 16:37:00 I [callback.py:41] eval_result :
# {'SpanFPreRecMetric': {'f-org': 0.793798, 'pre-org': 0.807571, 'rec-org': 0.780488, 'f-per': 0.877254, 'pre-per': 0.902994, 'rec-per': 0.852941, 'f-loc': 0.890823, 'pre-loc': 0.917436, 'rec-loc': 0.86571, 'f': 0.862476, 'pre': 0.885305, 'rec': 0.840796}}
# 2020-05-19 16:37:00 I [callback.py:46] reach early stopping patience, stop training.
# 2020-05-19 16:37:00 I [callback.py:55] Early Stopping triggered in epoch 49!
# 2020-05-19 16:37:00 W [<ipython-input-7-a0a0304e06bd>:19] 训练后评估
# Evaluate data in 5.79 seconds!
# Reloaded the best model.
#
# In Epoch:38/Step:24776, got best dev performance:
# SpanFPreRecMetric: f-org=0.821762, pre-org=0.838266, rec-org=0.805894, f-per=0.892734, pre-per=0.910588, rec-per=0.875566, f-loc=0.897778, pre-loc=0.916222, rec-loc=0.880062, f=0.87702, pre=0.894823, rec=0.859911
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=73.0), HTML(value='')), layout=Layout(dis…
# 2020-05-19 16:37:07 I [<ipython-input-7-a0a0304e06bd>:22] 评估结果：
# {'SpanFPreRecMetric': {'f-org': 0.800742, 'pre-org': 0.811853, 'rec-org': 0.789931, 'f-per': 0.896665, 'pre-per': 0.914158, 'rec-per': 0.879828, 'f-loc': 0.872016, 'pre-loc': 0.885787, 'rec-loc': 0.858666, 'f': 0.857708, 'pre': 0.871551, 'rec': 0.844297}}
# Evaluate data in 7.13 seconds!
# [tester]
# SpanFPreRecMetric: f-org=0.800742, pre-org=0.811853, rec-org=0.789931, f-per=0.896665, pre-per=0.914158, rec-per=0.879828, f-loc=0.872016, pre-loc=0.885787, rec-loc=0.858666, f=0.857708, pre=0.871551, rec=0.844297
